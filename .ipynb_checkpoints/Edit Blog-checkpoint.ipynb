# %%
blog_title_str = '2020-06-05 12:29 UTC+8 桃園龜山站地震預報：(1)綠：30天以內，日本(東京、京都或廣島附近)，M8+~M9+ (2)紫：10天以內，南加州、內華達州、南日本、南太平洋、中美洲或義大利附近，M7+~M8+ 桃園亀山局地震予報：(1)綠：30日間以內に、日本(東京、京都または広島付近)、M8+~M9+ (2)紫：10日間以內に、南カリフォルニア、ネバダ、南日本、南太平洋、中央アメリカまたはイタリア付近、M7+~M8+ Taoyuan Guishan Station Quake Forecast: (1)Green: Within 30 days, Japan(Near Tokyo, Kyoto or Hiroshima), M8+~M9+ (2)Purple: Within 10 days, Near Southern California, Nevada, Southern Japan, South Pacific, Central America or Italy, M7+~M8+'

Patreon_address = get_Patreon_address()
text_Facebook = blog_title_str + '\n' + Patreon_address
text_Facebook
# Out:
# '2020-06-05 12:29 UTC+8 桃園龜山站地震預報：(1)綠：30天以內，日本(東京、京都或廣島附近)，M8+~M9+ (2)紫：10天以內，南加州、內華達州、南日本、南太平洋、中美洲或義大利附近，M7+~M8+ 桃園亀山局地震予報：(1)綠：30日間以內に、日本(東京、京都または広島付近)、M8+~M9+ (2)紫：10日間以內に、南カリフォルニア、ネバダ、南日本、南太平洋、中央アメリカまたはイタリア付近、M7+~M8+ Taoyuan Guishan Station Quake Forecast: (1)Green: Within 30 days, Japan(Near Tokyo, Kyoto or Hiroshima), M8+~M9+ (2)Purple: Within 10 days, Near Southern California, Nevada, Southern Japan, South Pacific, Central America or Italy, M7+~M8+\nhttps://www.patreon.com/posts/37909168'

# %%
def post_to_Facebook_QuakeTomato(text):
    click_Facebook_tab()

    pyautogui.moveTo(1425, 117)
    time.sleep(1)
    
    pyautogui.click()
    time.sleep(1)
    
    pyautogui.moveTo(331, 580)
    time.sleep(1)
    
    pyautogui.click()
    time.sleep(1)

    pyautogui.moveTo(713, 970)
    time.sleep(1)
    
    pyautogui.scroll(10000) # scroll up
    time.sleep(1)

    #pyautogui.scroll(-200) # scroll down
    #time.sleep(1)
    
    pyautogui.moveTo(713, 970)
    time.sleep(1)
    
    pyautogui.click()
    time.sleep(1)

    pyperclip.copy(text) # copy to clipboard
    pyautogui.hotkey('ctrl', 'v') # paste from clipboard
    time.sleep(1)

    pyautogui.scroll(-2000) # scroll down
    time.sleep(1)

# %%
#text_Facebook = ''

post_to_Facebook_QuakeTomato(text_Facebook)

# %%
    locate_and_click('Facebook_Fan_Page_Publish_button.png')
    #pyautogui.moveTo(713, 814)
    time.sleep(10)
    
    pyautogui.scroll(-1000) # scroll down
    time.sleep(1)

'''
    pyautogui.click() # click Publish button
    time.sleep(1)

    #pyautogui.press('enter')
    #time.sleep(1)
    
'''
# Out:
# "\n    pyautogui.click() # click Publish button\n    time.sleep(1)\n\n    #pyautogui.press('enter')\n    #time.sleep(1)\n    \n"

# %%
import pyautogui
import time
import pyperclip

pyautogui.PAUSE = 0.1
pyautogui.FAILSAFE = True

def locate_and_click(png_file_name):
    try:
        (x, y) = pyautogui.locateCenterOnScreen(png_file_name)
        
        pyautogui.moveTo(x, y)
        time.sleep(1)
        
        pyautogui.click(x, y)
        time.sleep(1)
    except:
        print('Cannot locate:' + png_file_name)
    
def click_Blogger_tab():
    try:
        pyautogui.moveTo(650, 30)
        time.sleep(1)
        pyautogui.click()
        time.sleep(1)
    except:
        print('Cannot click Blogger tab.')
        
def click_Blog_Title():
    pyautogui.moveTo(900, 235)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)

def click_Facebook_Publish_button():
    locate_and_click('FacebookPublishButton.png')    
    
def click_Super_Big_button():
    locate_and_click('SuperBigButton.png')
    
def click_Add_Image_Title_button():
    locate_and_click('TitleButton.png')
    
def click_Add_Image_Title_field():
    locate_and_click('TitleField.png')
    
def click_Font_Size():
    pyautogui.moveTo(775, 295)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)
    
def scroll_down():
    pyautogui.moveTo(1100, 600)
    time.sleep(1)
    pyautogui.scroll(-10000) # scroll down
    time.sleep(1)
    
def click_Edit_area():    
    # click bottom of Edit area
    pyautogui.moveTo(575, 1010)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)
    
def click_image(y):
    scroll_down()
    time.sleep(1)
    x = 700       
    pyautogui.moveTo(x, y)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)
    
def get_file_location(file_number, file_type='original'):
    if ((file_type is 'analysis') | (file_type is 'old')):
        x = 160
    else: # 'original' or 'new'
        x = 53
    
    y = 80 + (file_number - 1) * 148
    return (x, y)

def get_file_name_location(file_number, file_type='original'):
    if ((file_type is 'analysis') | (file_type is 'old')):
        x = 160
    else: # 'original' or 'new'
        x = 53
    
    y = 114 + (file_number - 1) * 148
    return (x, y)

def get_file_name(file_number, file_type='original'):
    (file_x, file_y) = get_file_location(file_number, file_type)
    pyautogui.moveTo(file_x, file_y)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)

    (file_name_x, file_name_y) = get_file_name_location(file_number, file_type)
    pyautogui.moveTo(file_name_x, file_name_y)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)
    
    pyautogui.rightClick()
    for i in range(3):
        pyautogui.press('down')
        
    pyautogui.press('c') # copy file name to clipboard
    time.sleep(0.5)
    
    file_name = pyperclip.paste() # read file name from clipboard
    return file_name

def duplicate_file():
    pyautogui.rightClick()
    time.sleep(1)
    for i in range(5):
        pyautogui.press('up')
    pyautogui.press('c')
    
    pyautogui.moveRel(100, 0)
    pyautogui.rightClick()
    for i in range(4):
        pyautogui.press('down')
    pyautogui.press('p')
    time.sleep(1)
    
# Ramane file_name to file_name - Analysis
def rename_file():
    pyautogui.click()
    time.sleep(1)
    pyautogui.moveRel(0, 34)
    pyautogui.click()
    time.sleep(1)
    pyautogui.press('end')
    for i in range(4):
        pyautogui.press('left')
    for i in range(2):
        pyautogui.press('backspace')
    pyautogui.typewrite('Analysis')
    pyautogui.press('enter')
    
# Open file with Painter
def open_file():
    pyautogui.doubleClick()
    #time.sleep(7)
    time.sleep(3)
    
    # select Rectangle
    #pyautogui.moveTo(445, 65)
    pyautogui.moveTo(464, 67)
    pyautogui.click() 
    
    # select Red
    #pyautogui.moveTo(814, 62)
    
    # select Green
    pyautogui.moveTo(880, 62)
    
    # select Purple
    #pyautogui.moveTo(946, 62)
    
    # select Yellow
    #pyautogui.moveTo(858, 62)
    
    pyautogui.click() 
    
# Duplicate file, ramane it and open it with Painter
def analyze_file(file_number):
    (x, y) = get_file_location(file_number, 'original')
    pyautogui.moveTo(x, y)
    duplicate_file()
    rename_file()
    open_file()

def get_date_stamp():
    date_stamp = time.strftime("%Y-%m-%d")
    return date_stamp

def get_time_stamp():
    time_stamp = time.strftime("%Y-%m-%d")
    time_stamp += ' '
    time_stamp += time.strftime("%H:%M")
    time_stamp += ' UTC+8'
    return time_stamp

def get_new_file_name(old_file_name, date_stamp):
    splt_old_file_name = old_file_name.split()
    old_date_stamp = splt_old_file_name[0]
    old_date = old_date_stamp[0:10]
    
    if date_stamp is None:
        new_date_stamp = get_date_stamp()
    else:
        new_date_stamp = date_stamp
    
    new_date = new_date_stamp[0:10]
    
    if (new_date == old_date):
        new_date_stamp = new_date + '-2'
  
    new_file_name = old_file_name.replace(old_date_stamp, new_date_stamp)
    #print('New file name: ' + new_file_name)
  
    return new_file_name

def name_file(file_number, new_file_name):
    (x, y) = get_file_location(file_number, 'new')
    pyperclip.copy(new_file_name) # copy new file name to clipboard
    pyautogui.moveTo(x, y)
    time.sleep(0.5)
    pyautogui.click()
    time.sleep(1)
    
    (x, y) = get_file_name_location(file_number, 'new')
    pyautogui.moveTo(x, y)
    time.sleep(0.5)
    pyautogui.click()
    time.sleep(1)
  
    pyautogui.rightClick()
    time.sleep(1)
    for i in range(4):
        pyautogui.press('down')
        #time.sleep(0.5)
    pyautogui.press('p') # paste new file name from clip board
    time.sleep(1)
    pyautogui.press('enter')

def click_WeChat_icon():
    pyautogui.moveTo(1500, 1079)
    time.sleep(1)
    pyautogui.moveTo(613, 1060)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)

def click_WeChat_Edit_area():
    pyautogui.moveTo(1090, 935)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)
    
# Paste a file's name to WeChat and then drag it to WeChat
def drag_to_WeChat(file_number, file_type='original'):
    # copy file name to clipboard
    get_file_name(file_number, file_type)
    
    click_WeChat_icon()
    click_WeChat_Edit_area()

    # paste file name from clipboard
    pyautogui.hotkey('ctrl', 'v')
    time.sleep(1)
    pyautogui.press('enter')    
    time.sleep(1)

    (x, y) = get_file_location(file_number, file_type)
    pyautogui.moveTo(x, y)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)
    
    pyautogui.dragTo(1090, 935, 2)
    pyautogui.click()
    time.sleep(3)
    
    # click Send button
    x = 968
    y = 618
    pyautogui.moveTo(x, y)
    time.sleep(1)
    pyautogui.click()
    #time.sleep(3)
    time.sleep(1)

    #pyautogui.press('enter')    
    #time.sleep(1)
    
    click_WeChat_icon()
    
def name_new_file(file_number, date_stamp):
    old_file_name = get_file_name(file_number, 'old')
    time.sleep(1)
    new_file_name = get_new_file_name(old_file_name, date_stamp)
    time.sleep(1)
    name_file(file_number, new_file_name)

def name_new_files(file_number=1, to_WeChat=False, date_stamp=None):
    for i in range(file_number):
        name_new_file(i+1, date_stamp)
        
    if to_WeChat:
        for i in range(file_number):
            drag_to_WeChat(i+1)

def insert_enter():
    click_Blogger_tab()
    scroll_down()
    click_Edit_area()

    #click_Blogger_tab()
    #time.sleep(1)
    #click_Edit_area()
    #time.sleep(1)
    
    pyautogui.press('enter')
    time.sleep(1)
    
            
def insert_Analysis_file(file_number):    
    click_Blogger_tab()
    time.sleep(1)
    click_Edit_area()
    time.sleep(1)
    
    #print('file_number:', file_number)
    
    pyautogui.press('up')
    time.sleep(1)
    
    analysis_file_name = get_file_name(file_number, 'analysis')    
    (x, y) = get_file_location(file_number, 'analysis')
    
    pyautogui.moveTo(x, y)
    time.sleep(0.5)
    pyautogui.click()
    time.sleep(0.5)
    
    if (file_number == 1):
        (x, y) = (700, 400)
        pyautogui.dragTo(x, y, 2)
    else:
        (x, y) = (700, 957)
        #(x, y) = (700, 977)
        pyautogui.dragTo(x, y, 2)
    
    #time.sleep(7)
    #time.sleep(6)
    time.sleep(15)

    scroll_down()

    click_Edit_area()
    
    if (file_number == 1):
        click_image(500)
    else:
        click_image(957)
        #click_image(977)
        
    scroll_down()
    
    click_Super_Big_button()
    scroll_down()
    
    click_Add_Image_Title_button()
    time.sleep(1)
    scroll_down()
    time.sleep(1)
    
    click_Add_Image_Title_field()
    time.sleep(1)
    pyautogui.tripleClick()
    time.sleep(1)
    
    # paste file name from clipboard
    pyautogui.hotkey('ctrl', 'v')
    time.sleep(1)
    
    click_Font_Size()

    pyautogui.moveRel(0, 93)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)

    scroll_down()
    time.sleep(1)
    
    click_Edit_area()
    time.sleep(1)
    
    pyautogui.press('up')
    time.sleep(1)

def insert_Original_file(file_number):
    click_Blogger_tab()
    time.sleep(1)
    click_Edit_area()
    time.sleep(1)
    pyautogui.press('up')
    time.sleep(1)
    
    original_file_name = get_file_name(file_number, 'original')
    (x, y) = get_file_location(file_number, 'original')
    
    pyautogui.moveTo(x, y)
    time.sleep(0.5)
    pyautogui.click()
    time.sleep(0.5)
    
    pyautogui.dragTo(700, 957, 2)
    #time.sleep(7)
    #time.sleep(6)
    time.sleep(15)
    
    scroll_down()
    
    click_Edit_area()
    time.sleep(1)
    click_image(957)
    time.sleep(1)
    scroll_down()   
    
    click_Super_Big_button()
    time.sleep(1)
    scroll_down()
    
    click_Add_Image_Title_button()
    time.sleep(1)
    scroll_down()
    
    click_Add_Image_Title_field()
    time.sleep(1)
    pyautogui.tripleClick()
    time.sleep(1)
    
    # paste file name from clipboard
    pyautogui.hotkey('ctrl', 'v')
    time.sleep(1)
    
    click_Font_Size()
    time.sleep(1)

    pyautogui.moveRel(0, 93)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)

    scroll_down()
    time.sleep(1)
    click_Edit_area()
    time.sleep(1)
    pyautogui.press('up')
    time.sleep(1)

def insert_files(file_number=1):
    insert_enter()
    
    for i in range(1, file_number + 1):
        insert_Analysis_file(i)
        
    for i in range(1, file_number + 1):
        insert_Original_file(i)

def set_blog_title():
    click_Blogger_tab()
    click_Blog_Title()
    
    # paste from clipboard
    pyautogui.rightClick()
    pyautogui.press('down')
    pyautogui.press('down')
    pyautogui.press('p')
    pyautogui.press('enter')

def get_Quake_Forecast_title(quake_forecast, station_name, languages, time_stamp):
    blog_title = {}
    for language in languages:
        blog_title[language] = station_name[language]
        blog_title[language] += quake_forecast_title[language]
        quake_number = 0
        for quake in quake_forecast:
            quake_number += 1
            blog_title[language] += '('
            blog_title[language] += str(quake_number)
            blog_title[language] += ')'
            blog_title[language] += quake['color'][language]
            blog_title[language] += Within[language]
            blog_title[language] += str(quake['time'])
            blog_title[language] += Days[language]
            blog_title[language] += quake['location'][language]
            blog_title[language] += quake['magnitude']
            blog_title[language] += ' '
    
    blog_title_str = (time_stamp + ' ')
    
    for language in languages:
        blog_title_str += (blog_title[language])
    
    blog_title_str = blog_title_str.strip() # remove extra white space
    #print(blog_title_str)
    pyperclip.copy(blog_title_str) # copy to clipboard
    
    return (blog_title, blog_title_str)

def get_Quake_Forecast_text(quake_forecast, station_name, languages, time_stamp):
    blog_text = {}
    for language in languages:
        blog_text[language] = station_name[language]
        blog_text[language] += quake_forecast_title[language] + '\n'
        quake_number = 0
        for quake in quake_forecast:
            quake_number += 1
            blog_text[language] += '('
            blog_text[language] += str(quake_number)
            blog_text[language] += ')'
            blog_text[language] += quake['color'][language]
            blog_text[language] += Within[language]
            blog_text[language] += str(quake['time'])
            blog_text[language] += Days[language]
            blog_text[language] += quake['location'][language]
            blog_text[language] += quake['magnitude']
            blog_text[language] += '\n'
        blog_text[language] += '\n'    
        blog_text[language] += author[language]
        blog_text[language] += '\n'
        blog_text[language] += time_stamp
        blog_text[language] += '\n\n\n'

    blog_text_str = ''        
    for language in languages:
        blog_text_str += blog_text[language]
    blog_text_str = blog_text_str.strip() # remove extra white space
    #print(blog_text_str)
    pyperclip.copy(blog_text_str) # copy to clipboard
    
def get_Quake_Signals_title(signals, station_name, languages, time_stamp): 
    blog_title = {}
    for language in languages:
        blog_title[language] = station_name[language]
        blog_title[language] += quake_signals_title[language]
        blog_title[language] += Already_happened[language]
        quake_number = 0
        for quake in signals:
            quake_number += 1
            blog_title[language] += '('
            blog_title[language] += str(quake_number)
            blog_title[language] += ')'
            blog_title[language] += quake['color'][language]
            #blog_title[language] += Within[language]
            blog_title[language] += str(quake['time'])
            blog_title[language] += ' '
            blog_title[language] += quake['location'][language]
            blog_title[language] += ' '
            blog_title[language] += quake['magnitude']
            blog_title[language] += ' '
    
    blog_title_str = (time_stamp + ' ')
    
    for language in languages:
        blog_title_str += (blog_title[language])
    
    blog_title_str = blog_title_str.strip() # remove extra white space
    #print(blog_title_str)
    pyperclip.copy(blog_title_str) # copy to clipboard
    
    return (blog_title, blog_title_str)

def get_Quake_Signals_text(signals, station_name, languages, time_stamp):
    blog_text = {}
    for language in languages:
        blog_text[language] = station_name[language]
        blog_text[language] += quake_signals_title[language] + '\n'
        blog_text[language] += Already_happened[language] + '\n'
        quake_number = 0
        for quake in signals:
            quake_number += 1
            blog_text[language] += '('
            blog_text[language] += str(quake_number)
            blog_text[language] += ')'
            blog_text[language] += quake['color'][language]
            #blog_text[language] += Within[language]
            blog_text[language] += str(quake['time'])
            blog_text[language] += ' '
            #blog_text[language] += Days[language]
            blog_text[language] += quake['location'][language]
            blog_text[language] += ' '
            blog_text[language] += quake['magnitude']
            blog_text[language] += '\n'
        blog_text[language] += '\n'    
        blog_text[language] += author[language]
        blog_text[language] += '\n'
        blog_text[language] += time_stamp
        blog_text[language] += '\n\n\n'

    blog_text_str = ''        
    for language in languages:
        blog_text_str += blog_text[language]
    blog_text_str = blog_text_str.strip() # remove extra white space
    #print(blog_text_str)
    pyperclip.copy(blog_text_str) # copy to clipboard
    
def get_blog_address():
    click_Blogger_tab()

    pyautogui.moveTo(710, 61)
    time.sleep(1)
    #pyautogui.tripleClick()
    pyautogui.click() # click
    #time.sleep(0.1)
    pyautogui.click() # click
    #time.sleep(0.1)
    pyautogui.click() # click
    #time.sleep(0.1)
    
    pyautogui.rightClick()
    pyautogui.press('down')
    pyautogui.press('down')
    pyautogui.press('c') # copy blog address to clipboard
    blog_address = pyperclip.paste() # read blog address from clipboard
    return blog_address

def set_blog_text():
    click_Blogger_tab()
    scroll_down()
    click_Edit_area()
    pyautogui.press('backspace')

    pyautogui.hotkey('ctrl', 'v') # paste from clipboard
    #pyautogui.rightClick()
    #pyautogui.press('down')
    #pyautogui.press('down')
    #pyautogui.press('p') # paste from clipboard
    
def click_WeChat_icon():
    #pyautogui.moveTo(1000, 1079)
    pyautogui.moveTo(613, 1079)
    time.sleep(1)
    #pyautogui.moveTo(564, 1058)
    pyautogui.moveTo(613, 1060)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)
    
def click_WeChat_Edit_area():
    pyautogui.moveTo(1090, 935)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)
    
def post_to_WeChat():
    click_WeChat_icon()
    click_WeChat_Edit_area()
    
    # paste Quake Forecast from clipboard
    pyautogui.hotkey('ctrl', 'v')
    time.sleep(1)
    pyautogui.press('enter')
    time.sleep(1)
    
    # darg analysis file 1 to WeChat
    x = 160
    y = 70
    pyautogui.moveTo(x, y)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)
    
    pyautogui.dragTo(1090, 935, 2)
    #pyautogui.click()
    #time.sleep(1)
    time.sleep(3)
    
    # click Send button
    x = 968
    y = 618
    pyautogui.moveTo(x, y)
    time.sleep(1)
    pyautogui.click()
    #time.sleep(3)
    time.sleep(1)
    
    #pyautogui.press('enter')
    #time.sleep(3)
    click_WeChat_icon()
    time.sleep(1)
    
def click_Telegram_tab():
    (x, y) = (360, 30)
    pyautogui.moveTo(x, y)
    time.sleep(1)
    pyautogui.click() # click
    time.sleep(1)
    
def click_Telegram_Edit_area():
    (x, y) = (1020, 1013)
    pyautogui.moveTo(x, y)
    time.sleep(1)
    pyautogui.click() # click
    time.sleep(1)

def post_to_Telegram():
    click_Telegram_tab()
    click_Telegram_Edit_area()

    # paste Quake Forecast from clipboard
    pyautogui.hotkey('ctrl', 'v')
    time.sleep(1)
    pyautogui.press('enter')
    time.sleep(1)

def click_Patreon_tab():
    (x, y) = (450, 30)
    pyautogui.moveTo(x, y)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)
    
def click_Patreon_New_Post_button():
    (x, y) = (380, 486)
    pyautogui.moveTo(x, y)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)

def click_Patreon_Images_button():
    (x, y) = (1235, 465)
    pyautogui.moveTo(x, y)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)

def click_Patreon_Upload_Images_button():
    (x, y) = (1235, 705)
    pyautogui.moveTo(x, y)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)

def click_Patreon_Upload_Images_field():
    (x, y) = (521, 807)
    pyautogui.moveTo(x, y)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)

# paste analysis_file_name from clipboard
def paste_Patreon_analysis_file_name():
    pyautogui.hotkey('ctrl', 'v')
    time.sleep(1)
    pyautogui.press('down') # get the file name extention (.png)
    time.sleep(1)
    pyautogui.press('enter')
    time.sleep(5)

def click_Patreon_Public_button():
    click_Patreon_tab()
    
    pyautogui.moveTo(1200, 580)
    time.sleep(1)

    pyautogui.scroll(-5000) # scroll down
    time.sleep(1)
    
    pyautogui.moveTo(753, 200)
    time.sleep(1)
    
    pyautogui.click()
    time.sleep(1)
    

def paste_Patreon_title(title):
    click_Patreon_tab()

    pyautogui.moveTo(1200, 580)
    time.sleep(1)
    
    pyautogui.scroll(-5000) # scroll down
    time.sleep(1)
    
    pyautogui.scroll(1000) # scroll up
    time.sleep(1)

    # click title field
    pyautogui.moveTo(888, 695)
    time.sleep(1)
    
    pyautogui.click()
    time.sleep(1)

    pyperclip.copy(title) # copy to clipboard
    pyautogui.hotkey('ctrl', 'v') # paste from clipboard
    time.sleep(1)
    #pyautogui.press('enter')
    #time.sleep(1)
    
def paste_Patreon_text(text):
    click_Patreon_tab()

    pyautogui.moveTo(910, 812)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)

    pyperclip.copy(text) # copy to clipboard
    pyautogui.hotkey('ctrl', 'v') # paste from clipboard
    time.sleep(1)
    #pyautogui.press('enter')
    #time.sleep(1)

def click_Patreon_Publish_Now_button():
    click_Patreon_tab()
    
    pyautogui.moveTo(1207, 551)
    time.sleep(1)

    pyautogui.scroll(-5000) # scroll down
    time.sleep(1)
    
    pyautogui.click()
    time.sleep(5)
      
    
def post_to_Patreon(title, text):
    click_Patreon_tab()
    click_Patreon_New_Post_button()
    
    click_Patreon_Images_button()
    click_Patreon_Upload_Images_button()
    
    analysis_file_name = get_file_name(1, file_type='analysis') 
    click_Patreon_Upload_Images_field()
    paste_Patreon_analysis_file_name()
    
    click_Patreon_Public_button()
    paste_Patreon_title(title)
    paste_Patreon_text(text)
    
    click_Patreon_Publish_Now_button()

def get_Patreon_address():
    click_Patreon_tab()
    
    pyautogui.moveTo(710, 61)
    time.sleep(1)
    #pyautogui.tripleClick()
    pyautogui.click() # click
    #time.sleep(0.1)
    pyautogui.click() # click
    #time.sleep(0.1)
    pyautogui.click() # click
    #time.sleep(0.1)
    
    pyautogui.rightClick()
    pyautogui.press('down')
    pyautogui.press('down')
    pyautogui.press('c') # copy address to clipboard
    Patreon_address = pyperclip.paste() # read address from clipboard
    
    return Patreon_address

def click_Facebook_tab():
    pyautogui.moveTo(565, 30)
    time.sleep(1)
    
    pyautogui.click()
    time.sleep(1)


def post_to_Facebook_dysondyson(text):
    click_Facebook_tab()

    pyautogui.moveTo(1425, 1075)
    time.sleep(1)
    
    pyautogui.scroll(10000) # scroll up
    time.sleep(1)

    pyautogui.scroll(-200) # scroll down
    time.sleep(1)
    
    pyautogui.moveTo(1150, 934)
    time.sleep(1)
    
    pyautogui.click()
    time.sleep(1)

    pyperclip.copy(text) # copy to clipboard
    pyautogui.hotkey('ctrl', 'v') # paste from clipboard
    time.sleep(1)

    pyautogui.moveTo(1058, 1053)
    time.sleep(1)
    
    pyautogui.click() # click Publish button
    time.sleep(5)

    #pyautogui.press('enter')
    #time.sleep(1)
    
    pyautogui.scroll(-1000) # scroll down
    time.sleep(1)
    
def post_to_Facebook_QuakeForecastInstitute(text):
    click_Facebook_tab()

    pyautogui.moveTo(1425, 117)
    time.sleep(1)
    
    pyautogui.click()
    time.sleep(1)
    
    pyautogui.moveTo(331, 526)
    time.sleep(1)
    
    pyautogui.click()
    time.sleep(1)

    pyautogui.moveTo(713, 970)
    time.sleep(1)
    
    pyautogui.scroll(10000) # scroll up
    time.sleep(1)

    pyautogui.scroll(-200) # scroll down
    time.sleep(1)
    
    pyautogui.moveTo(713, 970)
    time.sleep(1)
    
    pyautogui.click()
    time.sleep(1)

    pyperclip.copy(text) # copy to clipboard
    pyautogui.hotkey('ctrl', 'v') # paste from clipboard
    time.sleep(1)

    pyautogui.scroll(-1000) # scroll down
    time.sleep(1)
    
    locate_and_click('Facebook_Fan_Page_Publish_button.png')
    #pyautogui.moveTo(713, 814)
    time.sleep(10)
    
    pyautogui.scroll(-3000) # scroll down
    time.sleep(1)


def publish_blog():
    pyautogui.moveTo(1715, 219)
    time.sleep(5)
    pyautogui.click()
    time.sleep(1)
    
def view_blog():
    click_Blogger_tab()
    time.sleep(1)
    pyautogui.moveTo(833, 504)
    time.sleep(1)
    pyautogui.moveTo(833, 506)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)

def close_Blogger_article_list():
    click_Blogger_tab()
    time.sleep(1)
    
    pyautogui.click()
    time.sleep(1)
    
    pyautogui.rightClick()
    time.sleep(1)

    for i in range(0, 8):
        pyautogui.press('down')
    
    time.sleep(1)
    pyautogui.press('enter')

    pyautogui.moveRel(80, 0)
    time.sleep(2)
    
def post_Quake_Forecast(quake_forecast, station_name, time_stamp,
            blog_address, blog_title_str):
    # Post to Telegram and WeChat.

    Telegram_languages = ['Chinese', 'Japanese', 'English']
    (blog_title_Telegram, blog_title_str_Telegram) = get_Quake_Forecast_title(
        quake_forecast,
        station_name, 
        Telegram_languages, 
        time_stamp)
    post_text_Telegram = blog_title_str_Telegram + '\n' + blog_address
    pyperclip.copy(post_text_Telegram) # copy to clipboard
    post_to_Telegram()
    
    post_text_WeChat = blog_title_str + '\n' + blog_address    
    pyperclip.copy(post_text_WeChat) # copy to clipboard
    post_to_WeChat()
    
    post_text_Patreon = post_text_WeChat
    post_to_Patreon(blog_title_str, post_text_Patreon)
    
    Patreon_address = get_Patreon_address()
    text_Facebook = blog_title_str + '\n' + Patreon_address
    post_to_Facebook_dysondyson(text_Facebook)    
    post_to_Facebook_QuakeForecastInstitute(text_Facebook)
    
    
    

def publish_Quake_Forecast(quake_forecast, station_name, languages, time_stamp):
    (blog_title, blog_title_str) = get_Quake_Forecast_title(quake_forecast, 
                                          station_name, languages, time_stamp)
    set_blog_title()
    get_Quake_Forecast_text(quake_forecast, station_name, languages, time_stamp)
    set_blog_text()
    publish_blog()
    time.sleep(15)
    return (blog_title, blog_title_str)    

def post_to_Facebook(tab_number):
    click_Facebook_tab()
    
    # click Post field
    if tab_number is 1:
        #(x, y) = (1244, 945)
        (x, y) = (1425, 1075)
        pyautogui.moveTo(x, y)
        time.sleep(1)
        pyautogui.scroll(10000) # scroll up
        #pyautogui.scroll(50) # scroll down a little
        pyautogui.scroll(200) # scroll down a little
        time.sleep(1)
    elif tab_number is 2:
        (x, y) = (720, 980)
        pyautogui.moveTo(x, y)
        time.sleep(1)
        pyautogui.scroll(10000) # scroll up
        time.sleep(1) 
    elif tab_number is 3:
        #(x, y) = (780, 950)
        (x, y) = (760, 1035)
        pyautogui.moveTo(x, y)
        time.sleep(1)
        pyautogui.scroll(10000) # scroll up
        time.sleep(1)
        pyautogui.scroll(-100) # scroll down
        time.sleep(1)
    else:
        print('Wrong tab number:', str(tab_number))
        
    pyautogui.moveTo(x, y)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)

    # paste Quake Forecast from clipboard
    pyautogui.hotkey('ctrl', 'v')
    time.sleep(4)
    
    if tab_number is 1:
        pyautogui.moveTo(x+100, y)
        time.sleep(1)
        pyautogui.scroll(-700) # scroll down
        time.sleep(2)
        
        for i in range(0, 11):
            pyautogui.press('tab')
            time.sleep(1)
        pyautogui.press('enter')
        time.sleep(1)
    elif tab_number is 2:
        pyautogui.moveTo(x+100, y)
        time.sleep(1)
        pyautogui.scroll(-700) # scroll down
        time.sleep(2)
        
        for i in range(0, 17):
            pyautogui.press('tab')
            time.sleep(1)
        pyautogui.press('enter')
        time.sleep(1)
    elif tab_number is 3:
        for i in range(0, 12):
            pyautogui.press('tab')
            time.sleep(1)
        pyautogui.press('enter')
        time.sleep(1)
    else:
        print('Wrong tab number:', str(tab_number))
    
    time.sleep(1)
    
quake_forecast_title = {
    'Chinese': '地震預報：',
    'Japanese': '地震予報：',
    'English': 'Quake Forecast: '
}

quake_signals_title = {
    'Chinese': '地震訊號：',
    'Japanese': '地震信号：',
    'English': 'Quake Signals: '
}

author = {
    'Chinese': '台灣地震預測研究所 所長\n林湧森',
    'Japanese': '台湾地震予測研究所 所長\n林湧森',
    'English': 'Dyson Lin\nFounder & CEO of Taiwan Quake Forecast Institute'}

Already_happened = {
    'Chinese': '已經發生：',
    'Japanese': '発生しました：',
    'English': 'Already happened: '}

Within = {
    'Chinese': '',
    'Japanese': '',
    'English': 'Within '}

Days = {
    'Chinese': '天以內，',
    'Japanese': '日間以內に、',
    'English': ' days, '}

Red = {
    'Chinese': '紅：',
    'Japanese': '赤：',
    'English': 'Red: '}

Orange = {
    'Chinese': '橙：',
    'Japanese': 'オレンジ：',
    'English': 'Orange: '}

Yellow = {
    'Chinese': '黃：',
    'Japanese': '黃：',
    'English': 'Yellow: '}

Green = {
    'Chinese': '綠：',
    'Japanese': '綠：',
    'English': 'Green: '}

Blue = {
    'Chinese': '藍：',
    'Japanese': '青：',
    'English': 'Blue: '}

Purple = {
    'Chinese': '紫：',
    'Japanese': '紫：',
    'English': 'Purple: '}



station = {}

station['宜蘭站'] = {
    'Chinese': '宜蘭站', 
    'Japanese': '宜蘭局', 
    'English': 'Yilan Station '}

station['上海站'] = {
    'Chinese': '上海站', 
    'Japanese': '上海局', 
    'English': 'Shanghai Station '}

station['洛杉磯站'] = {
    'Chinese': '洛杉磯站', 
    'Japanese': 'ロサンゼルス局', 
    'English': 'Los Angeles Station '}

station['新竹綠光站'] = {
    'Chinese': '新竹綠光站', 
    'Japanese': '新竹綠光局', 
    'English': 'Hsinchu Green Light Station '}

station['南投草屯站'] = {
    'Chinese': '南投草屯站', 
    'Japanese': '南投草屯局', 
    'English': 'Nantou Caotun Station '}

station['台南熱心站'] = {
    'Chinese': '台南熱心站', 
    'Japanese': '台南熱心局', 
    'English': 'Tainan Hot Heart Station '}

station['台南喜福站'] = {
    'Chinese': '台南喜福站', 
    'Japanese': '台南喜福局', 
    'English': 'Tainan Joy & Luck Station '}

station['台南新生站'] = {
    'Chinese': '台南新生站', 
    'Japanese': '台南新生局', 
    'English': 'Tainan Xinsheng Station '}

station['桃園龜山站'] = {
    'Chinese': '桃園龜山站', 
    'Japanese': '桃園亀山局', 
    'English': 'Taoyuan Guishan Station '}

station['台中大里站'] = {
    'Chinese': '台中大里站', 
    'Japanese': '台中大里局', 
    'English': 'Taichung Dali Station '}

station['南非德本站'] = {
    'Chinese': '南非德本站', 
    'Japanese': '南アフリカ ダーバン局', 
    'English': 'Durban, South Africa Station '}

station['義大利法恩扎站'] = {
    'Chinese': '義大利法恩扎站', 
    'Japanese': 'イタリア ファエンツァ局', 
    'English': 'Faenza, Italy Station '}

station['義大利卡爾塔尼塞塔站'] = {
    'Chinese': '義大利卡爾塔尼塞塔站', 
    'Japanese': 'イタリア カルタニッセッタ局', 
    'English': 'Caltanissetta, Italy Station '}

station['紐西蘭奧克蘭站'] = {
    'Chinese': '紐西蘭奧克蘭站', 
    'Japanese': 'ニュージーランド オークランド局', 
    'English': 'Auckland, New Zealand Station '}

station['智利伊基克站'] = {
    'Chinese': '智利伊基克站', 
    'Japanese': 'チリ イキケ局', 
    'English': 'Iquique, Chile Station '}

station['加拿大列治文站'] = {
    'Chinese': '加拿大列治文站', 
    'Japanese': 'カナダ リッチモンド局', 
    'English': 'Richmond BC Canada Station '}

station['嘉義站'] = {
    'Chinese': '嘉義站', 
    'Japanese': '嘉義局', 
    'English': 'Chiayi Station '}

station['日本輻射值'] = {
    'Chinese': '日本輻射值', 
    'Japanese': '日本の放射線値', 
    'English': 'Japan Radiation Value '}

station['高雄前鎮站'] = {
    'Chinese': '高雄前鎮站', 
    'Japanese': '高雄前鎮局', 
    'English': 'Kaohsiung Cianjhen Station '}

station['高雄前鎮南站'] = {
    'Chinese': '高雄前鎮南站', 
    'Japanese': '高雄前鎮南局', 
    'English': 'Kaohsiung Cianjhen South Station '}

station['高雄小港站'] = {
    'Chinese': '高雄小港站', 
    'Japanese': '高雄小港局', 
    'English': 'Kaohsiung Xiaogang Station '}

station['智利聖地牙哥站'] = {
    'Chinese': '智利聖地牙哥站', 
    'Japanese': 'チリ サンディエゴ局', 
    'English': 'Santiago, Chile Station '}

station['屏東站'] = {
    'Chinese': '屏東站', 
    'Japanese': '屏東局', 
    'English': 'Pingtung Station '}

station['成都站'] = {
    'Chinese': '成都站', 
    'Japanese': '成都局', 
    'English': 'Chengdu Station '}

station['蘇州站'] = {
    'Chinese': '蘇州站', 
    'Japanese': '蘇州局', 
    'English': 'Suzhou Station '}

station['彰化站'] = {
    'Chinese': '彰化站', 
    'Japanese': '彰化局', 
    'English': 'Changhua Station '}

station['台中北區站'] = {
    'Chinese': '台中北區站', 
    'Japanese': '台中北區局', 
    'English': 'Taichung North Station '}

station['台南安南站'] = {
    'Chinese': '台南安南站', 
    'Japanese': '台南安南局', 
    'English': 'Tainan Annan Station '}

station['日本宇都宮站'] = {
    'Chinese': '日本宇都宮站', 
    'Japanese': '日本宇都宮局', 
    'English': 'Utsunomiya, Japan Station '}

station['日本東京站'] = {
    'Chinese': '日本東京站', 
    'Japanese': '日本東京局', 
    'English': 'Tokyo, Japan Station '}

station['新北站'] = {
    'Chinese': '新北站', 
    'Japanese': '新北局', 
    'English': 'New Taipei Station '}

station['台南東區站'] = {
    'Chinese': '台南東區站', 
    'Japanese': '台南東區局', 
    'English': 'Tainan East Station '}

station['花蓮吉安北站'] = {
    'Chinese': '花蓮吉安北站', 
    'Japanese': '花蓮吉安北局', 
    'English': 'Hualien Ji-An North Station '}

station['台北站'] = {
    'Chinese': '台北站', 
    'Japanese': '台北局', 
    'English': 'Taipei Station '}

station['竹北豆子埔公園站'] = {
    'Chinese': '竹北豆子埔公園站', 
    'Japanese': '竹北豆子埔公園局', 
    'English': 'Zhubei Douzipu Park Station '}

station['台東站'] = {
    'Chinese': '台東站', 
    'Japanese': '台東局', 
    'English': 'Taitung Station '}

station['桃園平鎮站'] = {
    'Chinese': '桃園平鎮站', 
    'Japanese': '桃園平鎮局', 
    'English': 'Taoyuan Pingzhen Station '}

station['桃園龍潭站'] = {
    'Chinese': '桃園龍潭站', 
    'Japanese': '桃園龍潭局', 
    'English': 'Taoyuan Longtan Station '}

station['基隆安樂站'] = {
    'Chinese': '基隆安樂站', 
    'Japanese': '基隆安樂局', 
    'English': 'Keelung Anle Station '}

station['花蓮站'] = {
    'Chinese': '花蓮站', 
    'Japanese': '花蓮局', 
    'English': 'Hualien Station '}

station['花蓮玉里站'] = {
    'Chinese': '花蓮玉里站', 
    'Japanese': '花蓮玉里局', 
    'English': 'Hualien Yuli Station '}

station['美國舊金山站'] = {
    'Chinese': '美國舊金山站', 
    'Japanese': '米国サンフランシスコ局', 
    'English': 'San Francisco, US Station '}

station['高雄大樹站'] = {
    'Chinese': '高雄大樹站', 
    'Japanese': '高雄大樹局', 
    'English': 'Kaohsiung Dashu Station '}

station['桃園山仔頂站'] = {
    'Chinese': '桃園山仔頂站', 
    'Japanese': '桃園山仔頂局', 
    'English': 'Taoyuan Shanziding Station '}

station['日本宮古島站'] = {
    'Chinese': '日本宮古島站', 
    'Japanese': '日本宮古島局', 
    'English': 'Miyako, Japan Station '}

station['花蓮吉安南站'] = {
    'Chinese': '花蓮吉安南站', 
    'Japanese': '花蓮吉安南局', 
    'English': 'Hualien Jian South Station '}

station['印度西里古里站'] = {
    'Chinese': '印度西里古里站', 
    'Japanese': 'インド シリグリ局', 
    'English': 'Siliguri, India Station '}

station['土耳其伊斯坦堡彭迪克站'] = {
    'Chinese': '土耳其伊斯坦堡彭迪克站', 
    'Japanese': 'トルコ イスタンブール ペンディク局', 
    'English': 'Istanbul Pendik, Turkey Station '}

station['美國聖地牙哥站'] = {
    'Chinese': '美國聖地牙哥站', 
    'Japanese': '米国サンディエゴ局', 
    'English': 'San Diego, US Station '}

station['義大利馬切拉塔站'] = {
    'Chinese': '義大利馬切拉塔站', 
    'Japanese': 'イタリア マチェラータ局', 
    'English': 'Macerata, Italy Station '}

station['土耳其伊斯坦堡庫科切梅切站'] = {
    'Chinese': '土耳其伊斯坦堡庫科切梅切站', 
    'Japanese': 'トルコ イスタンブール クチュクチェクメツェ局', 
    'English': 'Istanbul Kucukcekmece, Turkey Station '}

station['墨西哥特拉斯卡拉站'] = {
    'Chinese': '墨西哥特拉斯卡拉站', 
    'Japanese': 'メキシコ トラスカラ局', 
    'English': 'Tlaxcala, Mexico Station '}

station['日本大阪站'] = {
    'Chinese': '日本大阪站', 
    'Japanese': '日本大阪局', 
    'English': 'Osaka, Japan Station '}

station['土耳其巴勒克西爾站'] = {
    'Chinese': '土耳其巴勒克西爾站', 
    'Japanese': 'トルコ バルケシル局', 
    'English': 'Balikesir, Turkey Station '}

station['土耳其伊斯坦堡比於克切克梅傑站'] = {
    'Chinese': '土耳其伊斯坦堡比於克切克梅傑站', 
    'Japanese': 'トルコ イスタンブール ブユックチェクメジェ局', 
    'English': 'Buyukcekmece, Istanbul Turkey Station '}

station['土耳其伊斯坦堡錫那諾巴站'] = {
    'Chinese': '土耳其伊斯坦堡錫那諾巴站', 
    'Japanese': 'トルコ イスタンブール シナノバ局', 
    'English': 'Sinanoba, Istanbul, Turkey Station '}

station['土耳其哈塔伊伊斯肯德倫站'] = {
    'Chinese': '土耳其哈塔伊伊斯肯德倫站', 
    'Japanese': 'トルコ ハタイ イスケンデルン局', 
    'English': 'Iskenderun, Hatay, Turkey Station '}

station['土耳其埃爾祖魯姆站'] = {
    'Chinese': '土耳其埃爾祖魯姆站', 
    'Japanese': 'トルコ エルズルム局', 
    'English': 'Erzurum, Turkey Station '}

station['土耳其卡赫拉曼馬拉什站'] = {
    'Chinese': '土耳其卡赫拉曼馬拉什站', 
    'Japanese': 'トルコ カフラマンマラシュ局', 
    'English': 'Kahramanmaras, Turkey Station '}

station['土耳其巴勒克西爾卡里西站'] = {
    'Chinese': '土耳其巴勒克西爾卡里西站', 
    'Japanese': 'トルコ バルケシル カレシ局', 
    'English': 'Karesi, Balikesir, Turkey Station '}

station['土耳其伊斯坦堡貝利都茲站'] = {
    'Chinese': '土耳其伊斯坦堡貝利都茲站', 
    'Japanese': 'トルコ イスタンブール ベリドズ局', 
    'English': 'Beylikdüzü, Istanbul, Turkey Station '}

station['菲律賓馬尼拉站'] = {
    'Chinese': '菲律賓馬尼拉站', 
    'Japanese': 'フィリピン マニラ局', 
    'English': 'Manila, Philippines Station '}

station['日本熊本站'] = {
    'Chinese': '日本熊本站', 
    'Japanese': '日本熊本局', 
    'English': 'Kumamoto, Japan Station '}

# %%
click_Facebook_tab()

# %%
2019-12-24 19:03 UTC Colombia M6.0
2020-01-07 08:24 UTC Puerto Rico M6.4
2020-01-28 15:38 UTC Karpathos, Greece M5.5
2020-01-28 19:10 UTC Jamaica M7.7

# %%
insert_enter()
insert_Analysis_file(1)
insert_Analysis_file(2)
insert_Analysis_file(3)

# %%
日本熊本站開始運轉。
可喜可賀。

日本熊本局が稼動を開始しました。
喜ばしいです。

Kumamoto, Japan Station has started running.
Congratulations.

台灣地震預測研究所 所長 
林湧森
台湾地震予測研究所 所長 
林湧森
Dyson Lin
Founder & CEO, Taiwan Quake Forecast Institute
2020-05-21 22:03 UTC+8

# %%
2018-08-19 00:19 UTC Ndoi Island, Fiji M8.2
2019-05-26 07:41 UTC Lagunas, Peru M8.0
2019-07-06 03:19 UTC California M7.1
2019-08-29 15:07 UTC Oregon M6.3
2020-01-28 19:10 UTC Lucea, Jamaica M7.7

# %%
1994-01-17 12:30 UTC 加州 カリフォルニア California M6.7 
1995-01-16 20:46 UTC 日本 日本 Japan M6.9
2011-03-11 05:46 UTC 日本 日本 Japan M9.1

# %%
2019-11-26 02:54 UTC Mamurras, Albania M6.4
2020-01-24 17:55 UTC Elazig, Turkey M6.7
2020-02-23 16:00 UTC Near Van, Turkey M6.0
2020-05-02 12:51 UTC Ierapetra, Greece M6.6
        
2020-01-18 16:38 UTC Indonesia M6.0
2020-01-19 16:58 UTC Indonesia M6.1
2020-02-05 18:12 UTC Ujungpangkah, Indonesia M6.2
2020-02-06 13:40 UTC Pondaguitan, Philippines M6.0
2020-02-09 06:04 UTC Kokopo, Papua New Guinea M6.2
2020-03-18 17:45 UTC Kangin, Indonesia M6.2

2019-12-24 19:03 UTC Lejanias, Colombia M6.0
2020-01-07 08:24 UTC Indios, Puerto Rico 6.4
2020-01-28 19:10 UTC Lucea, Jamaica M7.7

# %%
1999-09-20 17:47 UTC 台灣 台湾 Taiwan M7.7

# %%
2020-01-28 19:10 UTC Lucea, Jamaica M7.7
2020-02-13 10:33 UTC Kuril Islands, Russia M7.0
2020-03-25 02:49 UTC Kuril Islands, Russia M7.5
2020-03-31 23:52 UTC Challis, Idaho M6.5
2020-04-18 08:25 UTC Chichi-shima, Japan M6.6
2020-04-19 20:39 UTC Ofunato, Japan M6.3
2020-04-25 02:53 UTC Panguna, Papua New Guinea M6.3
2020-05-02 12:51 UTC Ierapetra, Greece M6.6
2020-05-03 03:24 UTC Taitung, Taiwan M5.1
2020-05-06 13:53 UTC Saumlaki, Indonesia M6.8
2020-05-12 22:41 UTC Lata, Solomon Islands M6.6
2020-05-15 11:03 UTC Tonopah, Nevada M6.5
2020-05-18 04:18 UTC Ierapetra, Greece M5.3 
2020-05-18 23:22 UTC Gra Liyia, Greece M5.8
2020-05-22 08:46 UTC San Jose del Cabo, Mexico M6.1
2020-05-30 18:13 UTC Kushiro, Japan M5.6  
2020-05-31 05:09 UTC Lampa, Peru M6.0 
2020-06-03 07:35 UTC San Pedro de Atacama, Chile M6.8
2020-06-04 08:49 UTC Tobelo, Indonesia M6.4

# %%
name_new_files(file_number=4, to_WeChat=False, date_stamp='2020-06-04')

# %%
name_new_files(file_number=1, to_WeChat=True, date_stamp='2020-06-04')

# %%
analyze_file(1)

# %%
analyze_file(2)

# %%
analyze_file(3)

# %%
analyze_file(4)

# %%
insert_files(1)
# Out:
# ---------------------------------------------------------------------------
# FailSafeException                         Traceback (most recent call last)
# <ipython-input-76-a12d531a1b64> in <module>
# ----> 1 insert_files(1)
#
# <ipython-input-74-4d285d68c7e8> in insert_files(file_number)
#     452
#     453     for i in range(1, file_number + 1):
# --> 454         insert_Analysis_file(i)
#     455
#     456     for i in range(1, file_number + 1):
#
# <ipython-input-74-4d285d68c7e8> in insert_Analysis_file(file_number)
#     314     click_Blogger_tab()
#     315     time.sleep(1)
# --> 316     click_Edit_area()
#     317     time.sleep(1)
#     318
#
# <ipython-input-74-4d285d68c7e8> in click_Edit_area()
#      59 def click_Edit_area():
#      60     # click bottom of Edit area
# ---> 61     pyautogui.moveTo(575, 1010)
#      62     time.sleep(1)
#      63     pyautogui.click()
#
# C:\Anaconda3\lib\site-packages\pyautogui\__init__.py in moveTo(x, y, duration, tween, pause, logScreenshot, _pause)
#     829       None
#     830     """
# --> 831     failSafeCheck()
#     832     x, y = _unpackXY(x, y)
#     833
#
# C:\Anaconda3\lib\site-packages\pyautogui\__init__.py in failSafeCheck()
#    1255 def failSafeCheck():
#    1256     if FAILSAFE and tuple(position()) in FAILSAFE_POINTS:
# -> 1257         raise FailSafeException('PyAutoGUI fail-safe triggered from mouse moving to a corner of the screen. To disable this fail-safe, set pyautogui.FAILSAFE to False. DISABLING FAIL-SAFE IS NOT RECOMMENDED.')
#    1258
#    1259
#
# FailSafeException: PyAutoGUI fail-safe triggered from mouse moving to a corner of the screen. To disable this fail-safe, set pyautogui.FAILSAFE to False. DISABLING FAIL-SAFE IS NOT RECOMMENDED.

# %%
insert_enter()
insert_Analysis_file(1)
#insert_Analysis_file(2)
#insert_Analysis_file(3)
# Out:
# Cannot locate:SuperBigButton.png
# Cannot locate:TitleButton.png
# Cannot locate:TitleField.png

# %%
2020-05-16 23:09 UTC+8 San Francisco, US Station Quake Signals

# %%
San Francisco, US Station Quake Signals:
(1)Red: 2020-04-25 02:53 UTC Panguna, Papua New Guinea M6.3
(2)Orange: 2020-05-06 13:53 UTC Saumlaki, Indonesia M6.8
(3)Yellow: 2020-05-12 22:41 UTC Lata, Solomon Islands M6.6
(4)Green: 2020-05-15 11:03 UTC Tonopah, Nevada M6.5

Dyson Lin
Founder & CEO, Taiwan Quake Forecast Institute
2020-05-16 23:09 UTC+8
# Out:
#   File "<ipython-input-33-e8985ac25d71>", line 1
#     IRIS Guro and Kars stations devices crashed.
#             ^
# SyntaxError: invalid syntax

# %%
insert_enter()
insert_Analysis_file(1)
#insert_Analysis_file(2)

# %%
IRIS JEM - Erimo could predict the Hokkaido M5.6 quake 11 days before it happened.

# %%
IRIS JEM - Erimo could predict the Hokkaido M5.6 quake 11 days before it happened.

2020-05-30 18:13 UTC Kushiro, Japan M5.6
    
The problem is: IRIS has 2000+ stations.
I don't have time to check them all.
Usually, I only check IRIS Taiwan and Turkey stations.

For your own safety, please check the IRIS signals near your city.
If you find big signals, please tell me. Thanks!
    
Dyson Lin
Founder & CEO, Taiwan Quake Forecast Institute
2020-05-31 07:13 UTC+8

# %%
# Yellow

insert_files(1)
station_name = station['美國舊金山站']

languages = ['Chinese', 'Japanese', 'English']
quake_forecast = [
    {'color': Yellow,
     'time': 3,
     'location': {
        'Chinese': '北海道或俄羅斯，',
        'Japanese': '北海道またはロシア、',
        'English': 'Hokkaido or Russia, '},
     'magnitude': 'M5+~M6+'},
]
time_stamp = get_time_stamp()
(blog_title, blog_title_str) = publish_Quake_Forecast(quake_forecast, 
                                    station_name, languages, time_stamp)
view_blog()

# %%
close_Blogger_article_list()
blog_address = get_blog_address()

post_Quake_Forecast(quake_forecast, 
                    station_name, time_stamp, blog_address, blog_title_str)

# %%
# Red

insert_files(1)
station_name = station['宜蘭站']

languages = ['Chinese', 'Japanese', 'English']
quake_forecast = [
    {'color': Red,
     'time': 3,
     'location': {
        'Chinese': '日本(長野附近)，',
        'Japanese': '日本(長野付近 )、',
        'English': 'Japan(Near Nagano), '},
     'magnitude': 'M4+~M5+'},
]
time_stamp = get_time_stamp()
(blog_title, blog_title_str) = publish_Quake_Forecast(quake_forecast, 
                                    station_name, languages, time_stamp)
view_blog()

# %%
close_Blogger_article_list()
blog_address = get_blog_address()

post_Quake_Forecast(quake_forecast, 
                    station_name, time_stamp, blog_address, blog_title_str)

# %%
# Green

insert_files(1)
station_name = station['南非德本站']

languages = ['Chinese', 'Japanese', 'English']
quake_forecast = [
    {'color': Green,
     'time': 30,
     'location': {
        'Chinese': '日本(東京、京都或廣島附近)，',
        'Japanese': '日本(東京、京都または広島付近)、',
        'English': 'Japan(Near Tokyo, Kyoto or Hiroshima), '},
     'magnitude': 'M8+~M9+'},
]

time_stamp = get_time_stamp()
(blog_title, blog_title_str) = publish_Quake_Forecast(quake_forecast, 
                                    station_name, languages, time_stamp)
view_blog()

# %%
close_Blogger_article_list()
blog_address = get_blog_address()

post_Quake_Forecast(quake_forecast, 
                    station_name, time_stamp, blog_address, blog_title_str)

# %%
#insert_enter()
#insert_Analysis_file(1)
#insert_Original_file(1)

# %%
# Purple

insert_files(1)
station_name = station['新竹綠光站']

languages = ['Chinese', 'Japanese', 'English']
quake_forecast = [
    {'color': Purple,
     'time': 10,
     'location': {
        'Chinese': '南加州、內華達州、南日本、南太平洋、中美洲或義大利附近，',
        'Japanese': '南カリフォルニア、ネバダ、南日本、南太平洋、中央アメリカまたはイタリア付近、',
        'English': 'Near Southern California, Nevada, Southern Japan, South Pacific, Central America or Italy, '},
     'magnitude': 'M7+~M8+'},
]

time_stamp = get_time_stamp()
(blog_title, blog_title_str) = publish_Quake_Forecast(quake_forecast, 
                                    station_name, languages, time_stamp)
view_blog()

# %%
close_Blogger_article_list()
blog_address = get_blog_address()

post_Quake_Forecast(quake_forecast, 
                    station_name, time_stamp, blog_address, blog_title_str)
# Out:
# ---------------------------------------------------------------------------
# FailSafeException                         Traceback (most recent call last)
# <ipython-input-100-7ba120395302> in <module>
#       3
#       4 post_Quake_Forecast(quake_forecast,
# ----> 5                     station_name, time_stamp, blog_address, blog_title_str)
#
# <ipython-input-96-12dc8055a3af> in post_Quake_Forecast(quake_forecast, station_name, time_stamp, blog_address, blog_title_str)
#    1000     text_Facebook = blog_title_str + '\n' + Patreon_address
#    1001     post_to_Facebook_dysondyson(text_Facebook)
# -> 1002     post_to_Facebook_QuakeForecastInstitute(text_Facebook)
#    1003
#    1004
#
# <ipython-input-96-12dc8055a3af> in post_to_Facebook_QuakeForecastInstitute(text)
#     930     time.sleep(1)
#     931
# --> 932     pyautogui.scroll(-1000) # scroll down
#     933     time.sleep(1)
#     934
#
# C:\Anaconda3\lib\site-packages\pyautogui\__init__.py in scroll(clicks, x, y, pause, logScreenshot, _pause)
#     733       None
#     734     """
# --> 735     failSafeCheck()
#     736     if type(x) in (tuple, list):
#     737         x, y = x[0], x[1]
#
# C:\Anaconda3\lib\site-packages\pyautogui\__init__.py in failSafeCheck()
#    1255 def failSafeCheck():
#    1256     if FAILSAFE and tuple(position()) in FAILSAFE_POINTS:
# -> 1257         raise FailSafeException('PyAutoGUI fail-safe triggered from mouse moving to a corner of the screen. To disable this fail-safe, set pyautogui.FAILSAFE to False. DISABLING FAIL-SAFE IS NOT RECOMMENDED.')
#    1258
#    1259
#
# FailSafeException: PyAutoGUI fail-safe triggered from mouse moving to a corner of the screen. To disable this fail-safe, set pyautogui.FAILSAFE to False. DISABLING FAIL-SAFE IS NOT RECOMMENDED.

# %%
# Green, Purple

insert_files(1)
station_name = station['桃園龜山站']

languages = ['Chinese', 'Japanese', 'English']
quake_forecast = [
    {'color': Green,
     'time': 30,
     'location': {
        'Chinese': '日本(東京、京都或廣島附近)，',
        'Japanese': '日本(東京、京都または広島付近)、',
        'English': 'Japan(Near Tokyo, Kyoto or Hiroshima), '},
     'magnitude': 'M8+~M9+'},
    {'color': Purple,
     'time': 10,
     'location': {
        'Chinese': '南加州、內華達州、南日本、南太平洋、中美洲或義大利附近，',
        'Japanese': '南カリフォルニア、ネバダ、南日本、南太平洋、中央アメリカまたはイタリア付近、',
        'English': 'Near Southern California, Nevada, Southern Japan, South Pacific, Central America or Italy, '},
     'magnitude': 'M7+~M8+'},
]

time_stamp = get_time_stamp()
(blog_title, blog_title_str) = publish_Quake_Forecast(quake_forecast, 
                                    station_name, languages, time_stamp)
view_blog()

# %%
close_Blogger_article_list()
blog_address = get_blog_address()

post_Quake_Forecast(quake_forecast, 
                    station_name, time_stamp, blog_address, blog_title_str)

# %%
# Purple

insert_files(1)
station_name = station['土耳其哈塔伊伊斯肯德倫站']

languages = ['Chinese', 'Japanese', 'English']
quake_forecast = [
    {'color': Purple,
     'time': 30,
     'location': {
        'Chinese': '東土耳其或伊朗附近，',
        'Japanese': '東トルコまたはイラン付近、',
        'English': 'Near Eastern Turkey or Iran, '},
     'magnitude': 'M6+~M7+'},
]

time_stamp = get_time_stamp()
(blog_title, blog_title_str) = publish_Quake_Forecast(quake_forecast, 
                                    station_name, languages, time_stamp)
view_blog()

# %%
close_Blogger_article_list()
blog_address = get_blog_address()

post_Quake_Forecast(quake_forecast, 
                    station_name, time_stamp, blog_address, blog_title_str)
# Out:
# ---------------------------------------------------------------------------
# FailSafeException                         Traceback (most recent call last)
# <ipython-input-50-7ba120395302> in <module>
#       3
#       4 post_Quake_Forecast(quake_forecast,
# ----> 5                     station_name, time_stamp, blog_address, blog_title_str)
#
# <ipython-input-41-1a3580add2ba> in post_Quake_Forecast(quake_forecast, station_name, time_stamp, blog_address, blog_title_str)
#     995
#     996     post_text_Patreon = post_text_WeChat
# --> 997     post_to_Patreon(blog_title_str, post_text_Patreon)
#     998
#     999     Patreon_address = get_Patreon_address()
#
# <ipython-input-41-1a3580add2ba> in post_to_Patreon(title, text)
#     827     paste_Patreon_analysis_file_name()
#     828
# --> 829     click_Patreon_Public_button()
#     830     paste_Patreon_title(title)
#     831     paste_Patreon_text(text)
#
# <ipython-input-41-1a3580add2ba> in click_Patreon_Public_button()
#     749
#     750 def click_Patreon_Public_button():
# --> 751     click_Patreon_tab()
#     752
#     753     pyautogui.moveTo(1200, 580)
#
# <ipython-input-41-1a3580add2ba> in click_Patreon_tab()
#     706 def click_Patreon_tab():
#     707     (x, y) = (560, 30)
# --> 708     pyautogui.moveTo(x, y)
#     709     time.sleep(1)
#     710     pyautogui.click()
#
# C:\Anaconda3\lib\site-packages\pyautogui\__init__.py in moveTo(x, y, duration, tween, pause, logScreenshot, _pause)
#     829       None
#     830     """
# --> 831     failSafeCheck()
#     832     x, y = _unpackXY(x, y)
#     833
#
# C:\Anaconda3\lib\site-packages\pyautogui\__init__.py in failSafeCheck()
#    1255 def failSafeCheck():
#    1256     if FAILSAFE and tuple(position()) in FAILSAFE_POINTS:
# -> 1257         raise FailSafeException('PyAutoGUI fail-safe triggered from mouse moving to a corner of the screen. To disable this fail-safe, set pyautogui.FAILSAFE to False. DISABLING FAIL-SAFE IS NOT RECOMMENDED.')
#    1258
#    1259
#
# FailSafeException: PyAutoGUI fail-safe triggered from mouse moving to a corner of the screen. To disable this fail-safe, set pyautogui.FAILSAFE to False. DISABLING FAIL-SAFE IS NOT RECOMMENDED.

# %%
# Red

insert_files(1)
station_name = station['宜蘭站']

languages = ['Chinese', 'Japanese', 'English']
quake_forecast = [
    {'color': Red,
     'time': 3,
     'location': {
        'Chinese': '花蓮、宜蘭或沖繩附近)，',
        'Japanese': '花蓮、宜蘭または沖縄付近 )、',
        'English': 'Near Hualien, Yilan or Okinawa), '},
     'magnitude': 'M4+~M5+'},
]
time_stamp = get_time_stamp()
(blog_title, blog_title_str) = publish_Quake_Forecast(quake_forecast, 
                                    station_name, languages, time_stamp)
view_blog()

# %%
close_Blogger_article_list()
blog_address = get_blog_address()

post_Quake_Forecast(quake_forecast, 
                    station_name, time_stamp, blog_address, blog_title_str)
# Out:
# ---------------------------------------------------------------------------
# FailSafeException                         Traceback (most recent call last)
# <ipython-input-82-7ba120395302> in <module>
#       3
#       4 post_Quake_Forecast(quake_forecast,
# ----> 5                     station_name, time_stamp, blog_address, blog_title_str)
#
# <ipython-input-81-7eb0c3845872> in post_Quake_Forecast(quake_forecast, station_name, time_stamp, blog_address, blog_title_str)
#     999     Patreon_address = get_Patreon_address()
#    1000     text_Facebook = blog_title_str + '\n' + Patreon_address
# -> 1001     post_to_Facebook_dysondyson(text_Facebook)
#    1002     post_to_Facebook_QuakeForecastInstitute(text_Facebook)
#    1003
#
# <ipython-input-81-7eb0c3845872> in post_to_Facebook_dysondyson(text)
#     877     time.sleep(1)
#     878
# --> 879     pyautogui.click()
#     880     time.sleep(1)
#     881
#
# C:\Anaconda3\lib\site-packages\pyautogui\__init__.py in click(x, y, clicks, interval, button, duration, tween, pause, logScreenshot, _pause)
#     518     """
#     519     button = _translateButton(button)
# --> 520     failSafeCheck()
#     521     x, y = _unpackXY(x, y)
#     522
#
# C:\Anaconda3\lib\site-packages\pyautogui\__init__.py in failSafeCheck()
#    1255 def failSafeCheck():
#    1256     if FAILSAFE and tuple(position()) in FAILSAFE_POINTS:
# -> 1257         raise FailSafeException('PyAutoGUI fail-safe triggered from mouse moving to a corner of the screen. To disable this fail-safe, set pyautogui.FAILSAFE to False. DISABLING FAIL-SAFE IS NOT RECOMMENDED.')
#    1258
#    1259
#
# FailSafeException: PyAutoGUI fail-safe triggered from mouse moving to a corner of the screen. To disable this fail-safe, set pyautogui.FAILSAFE to False. DISABLING FAIL-SAFE IS NOT RECOMMENDED.

# %%
# Red

insert_files(1)
station_name = station['宜蘭站']

languages = ['Chinese', 'Japanese', 'English']
quake_forecast = [
    {'color': Red,
     'time': 3,
     'location': {
        'Chinese': '台東附近)，',
        'Japanese': '台東付近 )、',
        'English': 'Near Taitung), '},
     'magnitude': 'M4+~M5+'},
]
time_stamp = get_time_stamp()
(blog_title, blog_title_str) = publish_Quake_Forecast(quake_forecast, 
                                    station_name, languages, time_stamp)
view_blog()

# %%
close_Blogger_article_list()
blog_address = get_blog_address()

post_Quake_Forecast(quake_forecast, 
                    station_name, time_stamp, blog_address, blog_title_str)

# %%
# Red

insert_files(1)
station_name = station['宜蘭站']

languages = ['Chinese', 'Japanese', 'English']
quake_forecast = [
    {'color': Red,
     'time': 3,
     'location': {
        'Chinese': '北土耳其或俄羅斯(黑海附近)，',
        'Japanese': '北トルコまたはロシア(黒海付近)、',
        'English': 'Northern Turkey or Russia (near Black Sea), '},
     'magnitude': 'M5+~M6+'},
]
time_stamp = get_time_stamp()
(blog_title, blog_title_str) = publish_Quake_Forecast(quake_forecast, 
                                    station_name, languages, time_stamp)
view_blog()

# %%
close_Blogger_article_list()
blog_address = get_blog_address()

post_Quake_Forecast(quake_forecast, 
                    station_name, time_stamp, blog_address, blog_title_str)
# Out:
# ---------------------------------------------------------------------------
# FailSafeException                         Traceback (most recent call last)
# <ipython-input-61-7ba120395302> in <module>
#       3
#       4 post_Quake_Forecast(quake_forecast,
# ----> 5                     station_name, time_stamp, blog_address, blog_title_str)
#
# <ipython-input-58-1a3580add2ba> in post_Quake_Forecast(quake_forecast, station_name, time_stamp, blog_address, blog_title_str)
#     995
#     996     post_text_Patreon = post_text_WeChat
# --> 997     post_to_Patreon(blog_title_str, post_text_Patreon)
#     998
#     999     Patreon_address = get_Patreon_address()
#
# <ipython-input-58-1a3580add2ba> in post_to_Patreon(title, text)
#     828
#     829     click_Patreon_Public_button()
# --> 830     paste_Patreon_title(title)
#     831     paste_Patreon_text(text)
#     832
#
# <ipython-input-58-1a3580add2ba> in paste_Patreon_title(title)
#     770     time.sleep(1)
#     771
# --> 772     pyautogui.scroll(-5000) # scroll down
#     773     time.sleep(1)
#     774
#
# C:\Anaconda3\lib\site-packages\pyautogui\__init__.py in scroll(clicks, x, y, pause, logScreenshot, _pause)
#     733       None
#     734     """
# --> 735     failSafeCheck()
#     736     if type(x) in (tuple, list):
#     737         x, y = x[0], x[1]
#
# C:\Anaconda3\lib\site-packages\pyautogui\__init__.py in failSafeCheck()
#    1255 def failSafeCheck():
#    1256     if FAILSAFE and tuple(position()) in FAILSAFE_POINTS:
# -> 1257         raise FailSafeException('PyAutoGUI fail-safe triggered from mouse moving to a corner of the screen. To disable this fail-safe, set pyautogui.FAILSAFE to False. DISABLING FAIL-SAFE IS NOT RECOMMENDED.')
#    1258
#    1259
#
# FailSafeException: PyAutoGUI fail-safe triggered from mouse moving to a corner of the screen. To disable this fail-safe, set pyautogui.FAILSAFE to False. DISABLING FAIL-SAFE IS NOT RECOMMENDED.

# %%
# Red

insert_files(1)
station_name = station['宜蘭站']

languages = ['Chinese', 'Japanese', 'English']
quake_forecast = [
    {'color': Red,
     'time': 3,
     'location': {
        'Chinese': '土耳其(馬尼薩或巴勒克西爾附近)，',
        'Japanese': 'トルコ(マニサまたはバルケシル付近 )、',
        'English': 'Turkey(Near Manisa or Balikesir), '},
     'magnitude': 'M4+~M5+'},
]
time_stamp = get_time_stamp()
(blog_title, blog_title_str) = publish_Quake_Forecast(quake_forecast, 
                                    station_name, languages, time_stamp)
view_blog()

# %%
close_Blogger_article_list()
blog_address = get_blog_address()

post_Quake_Forecast(quake_forecast, 
                    station_name, time_stamp, blog_address, blog_title_str)

# %%
# Red

insert_files(1)
station_name = station['宜蘭站']

languages = ['Chinese', 'Japanese', 'English']
quake_forecast = [
    {'color': Red,
     'time': 3,
     'location': {
        'Chinese': '土耳其(西里夫里或博盧附近)，',
        'Japanese': 'トルコ(シリブリまたはボル付近 )、',
        'English': 'Turkey(Near Silivri or Bolu), '},
     'magnitude': 'M4+~M5+'},
]
time_stamp = get_time_stamp()
(blog_title, blog_title_str) = publish_Quake_Forecast(quake_forecast, 
                                    station_name, languages, time_stamp)
view_blog()

# %%
close_Blogger_article_list()
blog_address = get_blog_address()

post_Quake_Forecast(quake_forecast, 
                    station_name, time_stamp, blog_address, blog_title_str)

# %%
#insert_enter()
#insert_Analysis_file(1)
#insert_Original_file(1)

# %%
# Purple

insert_files(1)
station_name = station['宜蘭站']

languages = ['Chinese', 'Japanese', 'English']
quake_forecast = [
    {'color': Purple,
     'time': 10,
     'location': {
        'Chinese': '東土耳其(凡城附近)或伊朗，',
        'Japanese': '東トルコ(ヴァン付近)またはイラン、',
        'English': 'Eastern Turkey(Near Van) or Iran, '},
     'magnitude': 'M6+~M7+'},
]
time_stamp = get_time_stamp()
(blog_title, blog_title_str) = publish_Quake_Forecast(quake_forecast, 
                                    station_name, languages, time_stamp)
view_blog()

# %%
close_Blogger_article_list()
blog_address = get_blog_address()

post_Quake_Forecast(quake_forecast, 
                    station_name, time_stamp, blog_address, blog_title_str)

# %%
# Red

insert_files(1)
station_name = station['宜蘭站']

languages = ['Chinese', 'Japanese', 'English']
quake_forecast = [
    {'color': Red,
     'time': 3,
     'location': {
        'Chinese': '南土耳其或希臘，',
        'Japanese': '南トルコまたはギリシャ、',
        'English': 'Southern Turkey or Greece, '},
     'magnitude': 'M5+~M6+'},
]
time_stamp = get_time_stamp()
(blog_title, blog_title_str) = publish_Quake_Forecast(quake_forecast, 
                                    station_name, languages, time_stamp)
view_blog()

# %%
close_Blogger_article_list()
blog_address = get_blog_address()

post_Quake_Forecast(quake_forecast, 
                    station_name, time_stamp, blog_address, blog_title_str)

# %%
# Red

insert_files(1)
station_name = station['宜蘭站']

languages = ['Chinese', 'Japanese', 'English']
quake_forecast = [
    {'color': Red,
     'time': 3,
     'location': {
        'Chinese': '土耳其(埃拉澤、馬拉蒂亞或哈塔伊附近)，',
        'Japanese': 'トルコ(エラズー、マラティヤまたはハタイ付近 )、',
        'English': 'Turkey(Near Elazig, Malatya or Hatay), '},
     'magnitude': 'M4+~M5+'},
]
time_stamp = get_time_stamp()
(blog_title, blog_title_str) = publish_Quake_Forecast(quake_forecast, 
                                    station_name, languages, time_stamp)
view_blog()

# %%
close_Blogger_article_list()
blog_address = get_blog_address()

post_Quake_Forecast(quake_forecast, 
                    station_name, time_stamp, blog_address, blog_title_str)

# %%
# Red

insert_files(1)
station_name = station['宜蘭站']

languages = ['Chinese', 'Japanese', 'English']
quake_forecast = [
    {'color': Red,
     'time': 3,
     'location': {
        'Chinese': '南台灣(台東附近)，',
        'Japanese': '南台湾(台東付近)、',
        'English': 'Southern Taiwan(Near Taitung), '},
     'magnitude': 'M4+~M5+'},
]
time_stamp = get_time_stamp()
(blog_title, blog_title_str) = publish_Quake_Forecast(quake_forecast, 
                                    station_name, languages, time_stamp)
view_blog()

# %%
close_Blogger_article_list()
blog_address = get_blog_address()

post_Quake_Forecast(quake_forecast, 
                    station_name, time_stamp, blog_address, blog_title_str)
