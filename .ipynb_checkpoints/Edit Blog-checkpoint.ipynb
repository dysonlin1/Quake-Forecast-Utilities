# %%
import pyautogui
import time
import pyperclip
pyautogui.PAUSE = 0.4
pyautogui.FAILSAFE = True

def locate_and_click(png_file_name):
    try:
        # locate
        (x, y) = pyautogui.locateCenterOnScreen(png_file_name)
        
        # move mouse
        pyautogui.moveTo(x, y)
        time.sleep(1)
        
        # click
        pyautogui.click(x, y)
        time.sleep(1)
    except:
        print('Cannot locate:' + png_file_name)
    
def click_Blogger_tab():
    try:
        #locate_and_click('BloggerTab.png')
        #pyautogui.moveTo(831, 31)
        pyautogui.moveTo(770, 30)
        time.sleep(1)
        pyautogui.click()
        time.sleep(1)
    except:
        print('Cannot click Blogger tab.')
        
def click_Blog_Title():
    pyautogui.moveTo(900, 235)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)

def click_Facebook_Publish_button():
    locate_and_click('FacebookPublishButton.png')    
    
def click_Super_Big_button():
    locate_and_click('SuperBigButton.png')
    
def click_Add_Image_Title_button():
    locate_and_click('TitleButton.png')
    
def click_Add_Image_Title_field():
    locate_and_click('TitleField.png')
    
def click_Font_Size():
    pyautogui.moveTo(775, 295)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)
    
def scroll_down():
    pyautogui.moveTo(1100, 600)
    time.sleep(1)
    pyautogui.scroll(-10000) # scroll down
    time.sleep(1)
    
def click_Edit_area():    
    # click bottom of Edit area
    #pyautogui.moveTo(1100, 1000)
    pyautogui.moveTo(1100, 990)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)
    
def click_image(y):
    scroll_down()
    time.sleep(1)
    x = 700       
    pyautogui.moveTo(x, y)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)
    
def get_file_location(file_number, file_type='original'):
    if ((file_type is 'analysis') | (file_type is 'old')):
        x = 160
    else: # 'original' or 'new'
        x = 53
    
    y = 80 + (file_number - 1) * 148
    return (x, y)

def get_file_name_location(file_number, file_type='original'):
    if ((file_type is 'analysis') | (file_type is 'old')):
        x = 160
    else: # 'original' or 'new'
        x = 53
    
    y = 114 + (file_number - 1) * 148
    return (x, y)

def get_file_name(file_number, file_type='original'):
    (file_x, file_y) = get_file_location(file_number, file_type)
    pyautogui.moveTo(file_x, file_y)
    time.sleep(1)
    #time.sleep(0.5)
    pyautogui.click()
    time.sleep(1)

    (file_name_x, file_name_y) = get_file_name_location(file_number, file_type)
    pyautogui.moveTo(file_name_x, file_name_y)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)
    
    pyautogui.rightClick()
    for i in range(3):
        pyautogui.press('down')
        
    pyautogui.press('c') # copy file name to clipboard
    time.sleep(0.5)
    
    file_name = pyperclip.paste() # read file name from clipboard
    return file_name

def duplicate_file():
    pyautogui.rightClick()
    time.sleep(1)
    for i in range(5):
        pyautogui.press('up')
    pyautogui.press('c')
    
    pyautogui.moveRel(100, 0)
    pyautogui.rightClick()
    for i in range(4):
        pyautogui.press('down')
    pyautogui.press('p')
    time.sleep(1)
    
# Ramane file_name to file_name - Analysis
def rename_file():
    pyautogui.click()
    time.sleep(1)
    pyautogui.moveRel(0, 34)
    pyautogui.click()
    time.sleep(1)
    pyautogui.press('end')
    for i in range(4):
        pyautogui.press('left')
    for i in range(2):
        pyautogui.press('backspace')
    pyautogui.typewrite('Analysis')
    pyautogui.press('enter')
    
# Open file with Painter
def open_file():
    pyautogui.doubleClick()
    #time.sleep(7)
    time.sleep(3)
    pyautogui.moveTo(445, 65)
    pyautogui.click() # select Rectangle
    
    # select Red
    #pyautogui.moveTo(814, 62)
    
    # select Green
    #pyautogui.moveTo(880, 62)
    
    # select Purple
    #pyautogui.moveTo(946, 62)
    
    # select Yellow
    pyautogui.moveTo(858, 62)
    
    pyautogui.click() 
    
# Duplicate file, ramane it and open it with Painter
def analyze_file(file_number):
    (x, y) = get_file_location(file_number, 'original')
    pyautogui.moveTo(x, y)
    duplicate_file()
    rename_file()
    open_file()

def get_date_stamp():
    date_stamp = time.strftime("%Y-%m-%d")
    return date_stamp

def get_time_stamp():
    time_stamp = time.strftime("%Y-%m-%d")
    time_stamp += ' '
    time_stamp += time.strftime("%H:%M")
    time_stamp += ' UTC+8'
    return time_stamp

def get_new_file_name(old_file_name, date_stamp):
    splt_old_file_name = old_file_name.split()
    old_date_stamp = splt_old_file_name[0]
    old_date = old_date_stamp[0:10]
    
    if date_stamp is None:
        new_date_stamp = get_date_stamp()
    else:
        new_date_stamp = date_stamp
    
    new_date = new_date_stamp[0:10]
    
    if (new_date == old_date):
        new_date_stamp = new_date + '-2'
  
    new_file_name = old_file_name.replace(old_date_stamp, new_date_stamp)
    #print('New file name: ' + new_file_name)
  
    return new_file_name

def name_file(file_number, new_file_name):
    (x, y) = get_file_location(file_number, 'new')
    pyperclip.copy(new_file_name) # copy new file name to clipboard
    pyautogui.moveTo(x, y)
    time.sleep(0.5)
    pyautogui.click()
    time.sleep(1)
    
    (x, y) = get_file_name_location(file_number, 'new')
    pyautogui.moveTo(x, y)
    time.sleep(0.5)
    pyautogui.click()
    time.sleep(1)
  
    pyautogui.rightClick()
    time.sleep(1)
    for i in range(4):
        pyautogui.press('down')
        #time.sleep(0.5)
    pyautogui.press('p') # paste new file name from clip board
    time.sleep(1)
    pyautogui.press('enter')

def click_WeChat_icon():
    pyautogui.moveTo(1500, 1079)
    time.sleep(1)
    pyautogui.moveTo(564, 1058)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)

def click_WeChat_Edit_area():
    pyautogui.moveTo(1090, 935)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)
    
# Paste a file's name to WeChat and then drag it to WeChat
def drag_to_WeChat(file_number, file_type='original'):
    # copy file name to clipboard
    get_file_name(file_number, file_type)
    
    click_WeChat_icon()
    click_WeChat_Edit_area()

    # paste file name from clipboard
    pyautogui.hotkey('ctrl', 'v')

    (x, y) = get_file_location(file_number, file_type)
    pyautogui.moveTo(x, y)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)
    
    pyautogui.dragTo(1090, 935, 2)
    pyautogui.click()
    time.sleep(1)

    pyautogui.press('enter')    
    
    time.sleep(1)
    click_WeChat_icon()
    
def name_new_file(file_number, date_stamp):
    old_file_name = get_file_name(file_number, 'old')
    time.sleep(1)
    new_file_name = get_new_file_name(old_file_name, date_stamp)
    time.sleep(1)
    name_file(file_number, new_file_name)

def name_new_files(file_number=1, to_WeChat=False, date_stamp=None):
    for i in range(file_number):
        name_new_file(i+1, date_stamp)
        
    if to_WeChat:
        for i in range(file_number):
            drag_to_WeChat(i+1)

def insert_enter():
    click_Blogger_tab()
    time.sleep(1)
    click_Edit_area()
    time.sleep(1)
    
    pyautogui.press('enter')
    time.sleep(1)
    
            
def insert_Analysis_file(file_number):    
    click_Blogger_tab()
    time.sleep(1)
    click_Edit_area()
    time.sleep(1)
    
    print('file_number:', file_number)
    
    #if (file_number == 1):
    #    pyautogui.press('enter')
    #    time.sleep(1)
    
    pyautogui.press('up')
    time.sleep(1)
    
    analysis_file_name = get_file_name(file_number, 'analysis')    
    (x, y) = get_file_location(file_number, 'analysis')
    
    pyautogui.moveTo(x, y)
    time.sleep(0.5)
    pyautogui.click()
    time.sleep(0.5)
    
    if (file_number == 1):
        (x, y) = (700, 400)
        pyautogui.dragTo(x, y, 2)
    else:
        (x, y) = (700, 957)
        #(x, y) = (700, 977)
        pyautogui.dragTo(x, y, 2)
    
    #time.sleep(7)
    #time.sleep(6)
    time.sleep(15)

    scroll_down()

    click_Edit_area()
    
    if (file_number == 1):
        click_image(500)
    else:
        click_image(957)
        #click_image(977)
        
    scroll_down()
    
    click_Super_Big_button()
    scroll_down()
    
    click_Add_Image_Title_button()
    time.sleep(1)
    scroll_down()
    time.sleep(1)
    
    click_Add_Image_Title_field()
    time.sleep(1)
    pyautogui.tripleClick()
    time.sleep(1)
    
    # paste file name from clipboard
    pyautogui.hotkey('ctrl', 'v')
    time.sleep(1)
    
    click_Font_Size()

    pyautogui.moveRel(0, 93)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)

    scroll_down()
    time.sleep(1)
    
    click_Edit_area()
    time.sleep(1)
    
    pyautogui.press('up')
    time.sleep(1)

def insert_original_file(file_number):
    click_Blogger_tab()
    time.sleep(1)
    click_Edit_area()
    time.sleep(1)
    pyautogui.press('up')
    time.sleep(1)
    
    original_file_name = get_file_name(file_number, 'original')
    (x, y) = get_file_location(file_number, 'original')
    
    pyautogui.moveTo(x, y)
    time.sleep(0.5)
    pyautogui.click()
    time.sleep(0.5)
    
    pyautogui.dragTo(700, 957, 2)
    #time.sleep(7)
    #time.sleep(6)
    time.sleep(15)
    
    scroll_down()
    
    click_Edit_area()
    time.sleep(1)
    click_image(957)
    time.sleep(1)
    scroll_down()   
    
    click_Super_Big_button()
    time.sleep(1)
    scroll_down()
    
    click_Add_Image_Title_button()
    time.sleep(1)
    scroll_down()
    
    click_Add_Image_Title_field()
    time.sleep(1)
    pyautogui.tripleClick()
    time.sleep(1)
    
    # paste file name from clipboard
    pyautogui.hotkey('ctrl', 'v')
    time.sleep(1)
    
    click_Font_Size()
    time.sleep(1)

    pyautogui.moveRel(0, 93)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)

    scroll_down()
    time.sleep(1)
    click_Edit_area()
    time.sleep(1)
    pyautogui.press('up')
    time.sleep(1)

def insert_files(file_number=1):
    insert_enter()
    
    for i in range(1, file_number + 1):
        insert_Analysis_file(i)
        
    for i in range(1, file_number + 1):
        insert_original_file(i)

def set_blog_title():
    click_Blogger_tab()
    click_Blog_Title()
    
    # paste from clipboard
    pyautogui.rightClick()
    pyautogui.press('down')
    pyautogui.press('down')
    pyautogui.press('p')
    pyautogui.press('enter')

def get_Quake_Forecast_title(quake_forecast, station_name, languages, time_stamp):
    blog_title = {}
    for language in languages:
        blog_title[language] = station_name[language]
        blog_title[language] += quake_forecast_title[language]
        quake_number = 0
        for quake in quake_forecast:
            quake_number += 1
            blog_title[language] += '('
            blog_title[language] += str(quake_number)
            blog_title[language] += ')'
            blog_title[language] += quake['color'][language]
            blog_title[language] += Within[language]
            blog_title[language] += str(quake['time'])
            blog_title[language] += Days[language]
            blog_title[language] += quake['location'][language]
            blog_title[language] += quake['magnitude']
            blog_title[language] += ' '
    
    blog_title_str = (time_stamp + ' ')
    
    for language in languages:
        blog_title_str += (blog_title[language])
    
    blog_title_str = blog_title_str.strip() # remove extra white space
    #print(blog_title_str)
    pyperclip.copy(blog_title_str) # copy to clipboard
    
    return (blog_title, blog_title_str)

def get_Quake_Forecast_text(quake_forecast, station_name, languages, time_stamp):
    blog_text = {}
    for language in languages:
        blog_text[language] = station_name[language]
        blog_text[language] += quake_forecast_title[language] + '\n'
        quake_number = 0
        for quake in quake_forecast:
            quake_number += 1
            blog_text[language] += '('
            blog_text[language] += str(quake_number)
            blog_text[language] += ')'
            blog_text[language] += quake['color'][language]
            blog_text[language] += Within[language]
            blog_text[language] += str(quake['time'])
            blog_text[language] += Days[language]
            blog_text[language] += quake['location'][language]
            blog_text[language] += quake['magnitude']
            blog_text[language] += '\n'
        blog_text[language] += '\n'    
        blog_text[language] += author[language]
        blog_text[language] += '\n'
        blog_text[language] += time_stamp
        blog_text[language] += '\n\n\n'

    blog_text_str = ''        
    for language in languages:
        blog_text_str += blog_text[language]
    blog_text_str = blog_text_str.strip() # remove extra white space
    #print(blog_text_str)
    pyperclip.copy(blog_text_str) # copy to clipboard
    
def get_Quake_Signals_title(signals, station_name, languages, time_stamp): 
    blog_title = {}
    for language in languages:
        blog_title[language] = station_name[language]
        blog_title[language] += quake_signals_title[language]
        blog_title[language] += Already_happened[language]
        quake_number = 0
        for quake in signals:
            quake_number += 1
            blog_title[language] += '('
            blog_title[language] += str(quake_number)
            blog_title[language] += ')'
            blog_title[language] += quake['color'][language]
            #blog_title[language] += Within[language]
            blog_title[language] += str(quake['time'])
            blog_title[language] += ' '
            blog_title[language] += quake['location'][language]
            blog_title[language] += ' '
            blog_title[language] += quake['magnitude']
            blog_title[language] += ' '
    
    blog_title_str = (time_stamp + ' ')
    
    for language in languages:
        blog_title_str += (blog_title[language])
    
    blog_title_str = blog_title_str.strip() # remove extra white space
    #print(blog_title_str)
    pyperclip.copy(blog_title_str) # copy to clipboard
    
    return (blog_title, blog_title_str)

def get_Quake_Signals_text(signals, station_name, languages, time_stamp):
    blog_text = {}
    for language in languages:
        blog_text[language] = station_name[language]
        blog_text[language] += quake_signals_title[language] + '\n'
        blog_text[language] += Already_happened[language] + '\n'
        quake_number = 0
        for quake in signals:
            quake_number += 1
            blog_text[language] += '('
            blog_text[language] += str(quake_number)
            blog_text[language] += ')'
            blog_text[language] += quake['color'][language]
            #blog_text[language] += Within[language]
            blog_text[language] += str(quake['time'])
            blog_text[language] += ' '
            #blog_text[language] += Days[language]
            blog_text[language] += quake['location'][language]
            blog_text[language] += ' '
            blog_text[language] += quake['magnitude']
            blog_text[language] += '\n'
        blog_text[language] += '\n'    
        blog_text[language] += author[language]
        blog_text[language] += '\n'
        blog_text[language] += time_stamp
        blog_text[language] += '\n\n\n'

    blog_text_str = ''        
    for language in languages:
        blog_text_str += blog_text[language]
    blog_text_str = blog_text_str.strip() # remove extra white space
    #print(blog_text_str)
    pyperclip.copy(blog_text_str) # copy to clipboard
    
def get_blog_address():
    click_Blogger_tab()

    pyautogui.moveTo(710, 61)
    time.sleep(1)
    #pyautogui.tripleClick()
    pyautogui.click() # click
    #time.sleep(0.1)
    pyautogui.click() # click
    #time.sleep(0.1)
    pyautogui.click() # click
    #time.sleep(0.1)
    
    pyautogui.rightClick()
    pyautogui.press('down')
    pyautogui.press('down')
    pyautogui.press('c') # copy blog address to clipboard
    blog_address = pyperclip.paste() # read blog address from clipboard
    return blog_address

def set_blog_text():
    click_Blogger_tab()
    scroll_down()
    click_Edit_area()
    pyautogui.press('backspace')

    pyautogui.hotkey('ctrl', 'v') # paste from clipboard
    #pyautogui.rightClick()
    #pyautogui.press('down')
    #pyautogui.press('down')
    #pyautogui.press('p') # paste from clipboard
    
def click_Facebook_tab(tab_number):
    global Facebook_tab_1_x
    global Facebook_tab_2_x
    global Facebook_tab_3_x
    
    if tab_number is 1:
        (x, y) = (475, 30)
    elif tab_number is 2:
        (x, y) = (590, 30)
    elif tab_number is 3:
        (x, y) = (700, 30)
    else:
        print('Wrong tab number:', str(tab_number))
    
    pyautogui.moveTo(x, y)
    time.sleep(1)
    pyautogui.click() # click
    
def click_WeChat_icon():
    pyautogui.moveTo(1000, 1079)
    time.sleep(1)
    #pyautogui.moveTo(564, 1058)
    pyautogui.moveTo(611, 1058)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)
    
def click_WeChat_Edit_area():
    pyautogui.moveTo(1090, 935)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)
    
def post_to_WeChat():
    click_WeChat_icon()
    click_WeChat_Edit_area()
    
    # paste Quake Forecast from clipboard
    pyautogui.hotkey('ctrl', 'v')
    
    # darg analysis file 1 to WeChat
    x = 160
    y = 70
    pyautogui.moveTo(x, y)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)
    
    pyautogui.dragTo(1090, 935, 2)
    pyautogui.click()
    time.sleep(1)

    pyautogui.press('enter')
    time.sleep(3)
    click_WeChat_icon()
    time.sleep(1)
    
def click_Twitter_tab():
    (x, y) = (360, 30)
    pyautogui.moveTo(x, y)
    time.sleep(1)
    pyautogui.click() # click
    time.sleep(1)
    
def click_Twit_button():
    (x, y) = (455, 999)
    pyautogui.moveTo(x, y)
    time.sleep(1)
    pyautogui.click() # click
    time.sleep(1)

def click_Twitter_Edit_area():
    (x, y) = (1100, 350)
    pyautogui.moveTo(x, y)
    time.sleep(1)
    pyautogui.click() # click
    time.sleep(1)

def post_to_Twitter():
    click_Twitter_tab()
    click_Twit_button()
    click_Twitter_Edit_area()

    # paste Quake Forecast from clipboard
    pyautogui.hotkey('ctrl', 'v')
    time.sleep(1)
    
    # darg analysis file 1 to Twitter
    x = 160
    y = 70
    pyautogui.moveTo(x, y)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)
    
    pyautogui.dragTo(1100, 350, 2)
    pyautogui.click()
    time.sleep(1)

    for i in range(0, 8):
        pyautogui.press('tab')
        time.sleep(1)
    pyautogui.press('enter')
    
    time.sleep(3)
    
    #pyautogui.scroll(-100) # scroll down

def publish_blog():
    #pyautogui.moveTo(1717, 237)
    pyautogui.moveTo(1715, 219)
    time.sleep(5)
    pyautogui.click()
    #time.sleep(5)
    time.sleep(1)
    
def view_blog():
    click_Blogger_tab()
    time.sleep(1)
    pyautogui.moveTo(833, 504)
    #pyautogui.moveTo(833, 524)
    time.sleep(1)
    pyautogui.moveTo(833, 506)
    #pyautogui.moveTo(833, 526)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)

def close_Blogger_article_list():
    click_Blogger_tab()
    time.sleep(1)
    
    pyautogui.click()
    time.sleep(1)
    
    pyautogui.rightClick()
    time.sleep(1)

    for i in range(0, 7):
        pyautogui.press('down')
    
    time.sleep(1)
    pyautogui.press('enter')

    pyautogui.moveRel(80, 0)
    time.sleep(2)
    
def post_Quake_Forecast(quake_forecast, station_name, time_stamp,
            blog_address, blog_title_str):
    # Post to Twitter, WeChat and Facebook.

    #Twitter_languages = ['Chinese']
    #(blog_title_Twitter, blog_title_str_Twitter) = get_Quake_Forecast_title(quake_forecast,
    #                                            station_name, Twitter_languages, time_stamp)
    #post_text_Twitter = blog_title_str_Twitter + '\n' + blog_address
    #pyperclip.copy(post_text_Twitter) # copy to clipboard
    #post_to_Twitter()

    #Twitter_languages = ['Japanese']
    #(blog_title_Twitter, blog_title_str_Twitter) = get_Quake_Forecast_title(quake_forecast,
    #                                            station_name, Twitter_languages, time_stamp)
    #post_text_Twitter = blog_title_str_Twitter + '\n' + blog_address
    #pyperclip.copy(post_text_Twitter) # copy to clipboard
    #post_to_Twitter()

    Twitter_languages = ['English']
    (blog_title_Twitter, blog_title_str_Twitter) = get_Quake_Forecast_title(quake_forecast,
                                                station_name, Twitter_languages, time_stamp)
    post_text_Twitter = blog_title_str_Twitter + '\n' + blog_address
    pyperclip.copy(post_text_Twitter) # copy to clipboard
    post_to_Twitter()
    
    
    post_text = blog_title_str + '\n' + blog_address    
    pyperclip.copy(post_text) # copy to clipboard
    post_to_WeChat()

    pyperclip.copy(post_text) # copy to clipboard
    post_to_Facebook(1)

    pyperclip.copy(post_text) # copy to clipboard
    post_to_Facebook(2)

    pyperclip.copy(post_text) # copy to clipboard
    post_to_Facebook(3)

def publish_Quake_Forecast(quake_forecast, station_name, languages, time_stamp):
    (blog_title, blog_title_str) = get_Quake_Forecast_title(quake_forecast, 
                                          station_name, languages, time_stamp)
    set_blog_title()
    get_Quake_Forecast_text(quake_forecast, station_name, languages, time_stamp)
    set_blog_text()
    publish_blog()
    time.sleep(15)
    return (blog_title, blog_title_str)    

def post_to_Facebook(tab_number):
    click_Facebook_tab(tab_number)
    
    # click Post field
    if tab_number is 1:
        (x, y) = (1244, 945)
        pyautogui.moveTo(x, y)
        time.sleep(1)
        pyautogui.scroll(10000) # scroll up
        time.sleep(1)
    elif tab_number is 2:
        (x, y) = (720, 980)
        pyautogui.moveTo(x, y)
        time.sleep(1)
        pyautogui.scroll(10000) # scroll up
        time.sleep(1)
    elif tab_number is 3:
        #(x, y) = (780, 950)
        (x, y) = (760, 1035)
        pyautogui.moveTo(x, y)
        time.sleep(1)
        pyautogui.scroll(10000) # scroll up
        time.sleep(1)
        pyautogui.scroll(-100) # scroll down
        time.sleep(1)
    else:
        print('Wrong tab number:', str(tab_number))
        
    pyautogui.moveTo(x, y)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)

    # paste Quake Forecast from clipboard
    pyautogui.hotkey('ctrl', 'v')
    time.sleep(4)
    
    if tab_number is 1:
        pyautogui.moveTo(x+100, y)
        time.sleep(1)
        pyautogui.scroll(-700) # scroll down
        time.sleep(2)
        
        for i in range(0, 14):
            pyautogui.press('tab')
            time.sleep(1)
        pyautogui.press('enter')
        time.sleep(1)
    elif tab_number is 2:
        pyautogui.moveTo(x+100, y)
        time.sleep(1)
        pyautogui.scroll(-700) # scroll down
        time.sleep(2)
        
        for i in range(0, 17):
            pyautogui.press('tab')
            time.sleep(1)
        pyautogui.press('enter')
        time.sleep(1)
    elif tab_number is 3:
        for i in range(0, 28):
            pyautogui.press('tab')
            time.sleep(1)
        pyautogui.press('enter')
        time.sleep(1)
    else:
        print('Wrong tab number:', str(tab_number))
    
    time.sleep(1)
    
quake_forecast_title = {
    'Chinese': '地震預報：',
    'Japanese': '地震予報：',
    'English': 'Quake Forecast: '
}

quake_signals_title = {
    'Chinese': '地震訊號：',
    'Japanese': '地震信号：',
    'English': 'Quake Signals: '
}

author = {
    'Chinese': '台灣地震預測研究所 所長\n林湧森',
    'Japanese': '台湾地震予測研究所 所長\n林湧森',
    'English': 'Dyson Lin\nFounder & CEO, Taiwan Quake Forecast Institute'}

Already_happened = {
    'Chinese': '已經發生：',
    'Japanese': '発生しました：',
    'English': 'Already happened: '}

Within = {
    'Chinese': '',
    'Japanese': '',
    'English': 'Within '}

Days = {
    'Chinese': '天以內，',
    'Japanese': '日間以內に、',
    'English': ' days, '}

Red = {
    'Chinese': '紅：',
    'Japanese': '赤：',
    'English': 'Red: '}

Orange = {
    'Chinese': '橙：',
    'Japanese': 'オレンジ：',
    'English': 'Orange: '}

Yellow = {
    'Chinese': '黃：',
    'Japanese': '黃：',
    'English': 'Yellow: '}

Green = {
    'Chinese': '綠：',
    'Japanese': '綠：',
    'English': 'Green: '}

Blue = {
    'Chinese': '藍：',
    'Japanese': '青：',
    'English': 'Blue: '}

Purple = {
    'Chinese': '紫：',
    'Japanese': '紫：',
    'English': 'Purple: '}



station = {}

station['台灣各站'] = {
    'Chinese': '台灣各站', 
    'Japanese': '台湾各局', 
    'English': 'Taiwan Stations '}

station['宜蘭站'] = {
    'Chinese': '宜蘭站', 
    'Japanese': '宜蘭局', 
    'English': 'Yilan Station '}

station['上海站'] = {
    'Chinese': '上海站', 
    'Japanese': '上海局', 
    'English': 'Shanghai Station '}

station['洛杉磯站'] = {
    'Chinese': '洛杉磯站', 
    'Japanese': 'ロサンゼルス局', 
    'English': 'Los Angeles Station '}

station['新竹綠光站'] = {
    'Chinese': '新竹綠光站', 
    'Japanese': '新竹綠光局', 
    'English': 'Hsinchu Green Light Station '}

station['南投草屯站'] = {
    'Chinese': '南投草屯站', 
    'Japanese': '南投草屯局', 
    'English': 'Nantou Caotun Station '}

station['台南熱心站'] = {
    'Chinese': '台南熱心站', 
    'Japanese': '台南熱心局', 
    'English': 'Tainan Hot Heart Station '}

station['台南喜福站'] = {
    'Chinese': '台南喜福站', 
    'Japanese': '台南喜福局', 
    'English': 'Tainan Joy & Luck Station '}

station['台南新生站'] = {
    'Chinese': '台南新生站', 
    'Japanese': '台南新生局', 
    'English': 'Tainan Xinsheng Station '}

station['桃園龜山站'] = {
    'Chinese': '桃園龜山站', 
    'Japanese': '桃園亀山局', 
    'English': 'Taoyuan Guishan Station '}

station['台中大里站'] = {
    'Chinese': '台中大里站', 
    'Japanese': '台中大里局', 
    'English': 'Taichung Dali Station '}

station['南非德本站'] = {
    'Chinese': '南非德本站', 
    'Japanese': '南アフリカ ダーバン局', 
    'English': 'Durban, South Africa Station '}

station['義大利法恩扎站'] = {
    'Chinese': '義大利法恩扎站', 
    'Japanese': 'イタリア ファエンツァ局', 
    'English': 'Faenza, Italy Station '}

station['義大利卡爾塔尼塞塔站'] = {
    'Chinese': '義大利卡爾塔尼塞塔站', 
    'Japanese': 'イタリア カルタニッセッタ局', 
    'English': 'Caltanissetta, Italy Station '}

station['紐西蘭奧克蘭站'] = {
    'Chinese': '紐西蘭奧克蘭站', 
    'Japanese': 'ニュージーランド オークランド局', 
    'English': 'Auckland, New Zealand Station '}

station['智利伊基克站'] = {
    'Chinese': '智利伊基克站', 
    'Japanese': 'チリ イキケ局', 
    'English': 'Iquique, Chile Station '}

station['加拿大列治文站'] = {
    'Chinese': '加拿大列治文站', 
    'Japanese': 'カナダ リッチモンド局', 
    'English': 'Richmond BC Canada Station '}

station['嘉義站'] = {
    'Chinese': '嘉義站', 
    'Japanese': '嘉義局', 
    'English': 'Chiayi Station '}

station['日本輻射值'] = {
    'Chinese': '日本輻射值', 
    'Japanese': '日本の放射線値', 
    'English': 'Japan Radiation Value '}

station['高雄前鎮站'] = {
    'Chinese': '高雄前鎮站', 
    'Japanese': '高雄前鎮局', 
    'English': 'Kaohsiung Cianjhen Station '}

station['高雄前鎮南站'] = {
    'Chinese': '高雄前鎮南站', 
    'Japanese': '高雄前鎮南局', 
    'English': 'Kaohsiung Cianjhen South Station '}

station['高雄小港站'] = {
    'Chinese': '高雄小港站', 
    'Japanese': '高雄小港局', 
    'English': 'Kaohsiung Xiaogang Station '}

station['智利聖地牙哥站'] = {
    'Chinese': '智利聖地牙哥站', 
    'Japanese': 'チリ サンディエゴ局', 
    'English': 'Santiago, Chile Station '}

station['屏東站'] = {
    'Chinese': '屏東站', 
    'Japanese': '屏東局', 
    'English': 'Pingtung Station '}

station['成都站'] = {
    'Chinese': '成都站', 
    'Japanese': '成都局', 
    'English': 'Chengdu Station '}

station['蘇州站'] = {
    'Chinese': '蘇州站', 
    'Japanese': '蘇州局', 
    'English': 'Suzhou Station '}

station['彰化站'] = {
    'Chinese': '彰化站', 
    'Japanese': '彰化局', 
    'English': 'Changhua Station '}

station['台中北區站'] = {
    'Chinese': '台中北區站', 
    'Japanese': '台中北區局', 
    'English': 'Taichung North Station '}

station['台南安南站'] = {
    'Chinese': '台南安南站', 
    'Japanese': '台南安南局', 
    'English': 'Tainan Annan Station '}

station['日本宇都宮站'] = {
    'Chinese': '日本宇都宮站', 
    'Japanese': '日本宇都宮局', 
    'English': 'Utsunomiya, Japan Station '}

station['日本東京站'] = {
    'Chinese': '日本東京站', 
    'Japanese': '日本東京局', 
    'English': 'Tokyo, Japan Station '}

station['新北站'] = {
    'Chinese': '新北站', 
    'Japanese': '新北局', 
    'English': 'New Taipei Station '}

station['台南東區站'] = {
    'Chinese': '台南東區站', 
    'Japanese': '台南東區局', 
    'English': 'Tainan East Station '}

station['花蓮吉安北站'] = {
    'Chinese': '花蓮吉安北站', 
    'Japanese': '花蓮吉安北局', 
    'English': 'Hualien Jian North Station '}

station['台北站'] = {
    'Chinese': '台北站', 
    'Japanese': '台北局', 
    'English': 'Taipei Station '}

station['竹北豆子埔公園站'] = {
    'Chinese': '竹北豆子埔公園站', 
    'Japanese': '竹北豆子埔公園局', 
    'English': 'Zhubei Douzipu Park Station '}

station['台東站'] = {
    'Chinese': '台東站', 
    'Japanese': '台東局', 
    'English': 'Taitung Station '}

station['桃園平鎮站'] = {
    'Chinese': '桃園平鎮站', 
    'Japanese': '桃園平鎮局', 
    'English': 'Taoyuan Pingzhen Station '}

station['桃園龍潭站'] = {
    'Chinese': '桃園龍潭站', 
    'Japanese': '桃園龍潭局', 
    'English': 'Taoyuan Longtan Station '}

station['基隆安樂站'] = {
    'Chinese': '基隆安樂站', 
    'Japanese': '基隆安樂局', 
    'English': 'Keelung Anle Station '}

station['花蓮站'] = {
    'Chinese': '花蓮站', 
    'Japanese': '花蓮局', 
    'English': 'Hualien Station '}

station['花蓮玉里站'] = {
    'Chinese': '花蓮玉里站', 
    'Japanese': '花蓮玉里局', 
    'English': 'Hualien Yuli Station '}

station['美國舊金山站'] = {
    'Chinese': '美國舊金山站', 
    'Japanese': '米国サンフランシスコ局', 
    'English': 'San Francisco, US Station '}

station['高雄大樹站'] = {
    'Chinese': '高雄大樹站', 
    'Japanese': '高雄大樹局', 
    'English': 'Kaohsiung Dashu Station '}

station['桃園山仔頂站'] = {
    'Chinese': '桃園山仔頂站', 
    'Japanese': '桃園山仔頂局', 
    'English': 'Taoyuan Shanziding Station '}

station['日本宮古島站'] = {
    'Chinese': '日本宮古島站', 
    'Japanese': '日本宮古島局', 
    'English': 'Miyako, Japan Station '}

station['花蓮吉安南站'] = {
    'Chinese': '花蓮吉安南站', 
    'Japanese': '花蓮吉安南局', 
    'English': 'Hualien Jian South Station '}

station['荷蘭沙根站'] = {
    'Chinese': '荷蘭沙根站', 
    'Japanese': 'オランダ シャゲン局', 
    'English': 'Schagen, Netherlands Station '}

station['印度西里古里站'] = {
    'Chinese': '印度西里古里站', 
    'Japanese': 'インド シリグリ局', 
    'English': 'Siliguri, India Station '}

station['土耳其伊斯坦堡站'] = {
    'Chinese': '土耳其伊斯坦堡站', 
    'Japanese': 'トルコ イスタンブール局', 
    'English': 'Istanbul, Turkey Station '}

station['土耳其馬爾馬拉埃雷利西站'] = {
    'Chinese': '土耳其馬爾馬拉埃雷利西站', 
    'Japanese': 'トルコ マルマラ・エレリシ局', 
    'English': 'Marmara Ereğlisi, Turkey Station '}

station['土耳其西利布里亞站'] = {
    'Chinese': '土耳其西利布里亞站', 
    'Japanese': 'トルコ シリヴリ局', 
    'English': 'Silivri, Turkey Station '}

station['土耳其科賈埃利站'] = {
    'Chinese': '土耳其科賈埃利站', 
    'Japanese': 'トルコ コジャエリ局', 
    'English': 'Kocaeli, Turkey Station '}

'''
美國聖地牙哥站 
米国サンディエゴ局
San Diego, US Station

義大利馬切拉塔站
イタリア マチェラータ局
Macerata, Italy Station
'''
# Out:
# '\n美國聖地牙哥站 \n米国サンディエゴ局\nSan Diego, US Station\n\n義大利馬切拉塔站\nイタリア マチェラータ局\nMacerata, Italy Station\n'

# %%
# 2018-05-05 06:32 UTC+8 夏威夷 ハワイ Hawaii M6.9
# 2018-05-09 15:57 UTC+8 巴布亞紐幾內亞 パプアニューギニア Papua New Guinea M6.0
# 2018-05-18 09:45 UTC+8 紐西蘭 ニュージーランド New Zealand M6.2

# %%
# 2018-06-22 05:13 UTC+8 萬那杜 バヌアツ Vanuatu M6.1
# 2018-07-13 17:46 UTC+8 萬那杜 バヌアツ Vanuatu M6.4
# 2018-08-05 19:46 UTC+8 印尼 インドネシア Indonesia M6.9
# 2018-08-17 23:35 UTC+8 印尼 インドネシア Indonesia M6.5

# %%
# 2018-08-18 08:15 UTC+8 南投 南投 Nantou M5.1

# %%
# 2018-08-19 08:19 UTC+8 斐濟 フィジー Fiji M8.2
# 2018-09-06 02:07 UTC+8 北海道 北海道 Hokkaido M6.6
# 2018-09-06 23:49 UTC+8 斐濟 フィジー Fiji M7.8
# 2018-09-10 12:19 UTC+8 紐西蘭 ニュージーランド New Zealand M6.9 
# 2018-09-23 13:52 UTC+8 關島 グアム Guam M6.4
# 2018-09-28 18:02 UTC+8 印尼 インドネシア Indonesia M7.5
# 2018-10-11 04:48 UTC+8 巴布亞紐幾內亞 パプアニューギニア Papua New Guinea M7.0

# %%
# 2018-10-07 13:41 UTC+8 新竹 新竹 Hsinchu M3.6

# %%
# 2018-10-13 19:10 UTC+8 俄羅斯 ロシア Russia M6.7

# %%
# 2018-10-22 14:16 UTC+8 加拿大 カナダ Canada M6.8

# %%
# 2018-02-06 23:50 UTC+8 花蓮 花蓮 Hualien M6.2

# %%
##############################################################################

# %%
# 2018-10-23 12:34 UTC+8 花蓮 花蓮 Hualien M6.0
# 2018-11-26 07:57 UTC+8 澎湖 澎湖 Penghu M6.2
# 2019-04-12 19:40 UTC+8 印尼 インドネシア Indonesia M6.8
# 2019-04-18 13:01 UTC+8 花蓮 花蓮 Hualien M6.1

# %%
# 2018-10-25 03:34 UTC+8 台南 台南 Tainan M2.9

# %%
# 2018-10-26 02:36 UTC+8 日本宮城縣 日本宮城県 Ishinomaki, Japan M5.7

# %%
# 2018-12-04 12:17 UTC+8 嘉義 嘉義 Chiayi M3.3
# 2018-12-08 07:46 UTC+8 澎湖 澎湖 Penghu M3.7

# %%
# 2018-12-05 12:18 UTC+8 新喀里多尼亞 ニューカレドニア New Caledonia M7.5

# %%
# 2018-12-16 05:21 UTC+8 花蓮 花蓮 Hualien M5.6

# %%
# 2019-01-04 02:02 UTC+8 台東 台東 Taitung M4.7

# %%
# 2019-01-08 20:16 UTC+8 台東 M5.3

# %%
# 2019-01-30 20:00 UTC+8 宜蘭 M3.0
# 2019-01-30 18:05 UTC+8 宜蘭 M3.0

# %%
# 2019-02-06 18:25 UTC+8 菲律賓 フィリピン Philippines M5.4
# 2019-02-07 12:15 UTC+8 印尼 インドネシア Indonesia M5.7

# %%
# 2019-02-15 22:08 UTC+8 花蓮 花蓮 Hualien M5.0

# %%
# 2019-02-16 18:01 UTC+8 日本宮古島 日本宮古島 Hirara, Japan M5.2

# %%
# 2019-02-22 18:17 UTC+8 厄瓜多 エクアドル Ecuador M7.5
# 2019-03-01 16:50 UTC+8 秘魯 ペルー Peru M7.0

# %%
# 2019-03-02 11:22 UTC+8 日本根室市 日本根室市 Nemuro, Japan M6.0

# %%
# 2019-03-08 10:32 UTC+8 台東 台東 Taitung M5.2

# %%
# 2019-03-08 23:06 UTC+8 菲律賓 フィリピン Philippines M6.0

# %%
# 2019-03-24 03:21 UTC+8 哥倫比亞 コロンビア Colombia M6.1
# 2019-03-31 15:04 UTC+8 厄瓜多 エクアドル Ecuador M6.2

# %%
# 2019-04-12 19:40 UTC+8 印尼 インドネシア Indonesia M6.8
# 2019-04-18 13:01 UTC+8 花蓮 花蓮 Hualien M6.1
# 2019-04-18 22:46 UTC+8 印度-南極洲洋脊西部 西インド - 南極海嶺 Western Indian-Antarctic Ridge M6.5
# 2019-04-22 17:11 UTC+8 菲律賓 フィリピン Philippines M6.1
# 2019-04-23 13:37 UTC+8 菲律賓 フィリピン Philippines M6.4

# %%
'''

2015-09-17 06:54 UTC+8
智利 チリ Chile 
M8.3

2018-08-19 08:19 UTC+8 
斐濟 フィジー Fiji 
M8.2

2019-05-07 05:19 UTC+8 
巴布亞紐幾內亞 パプアニューギニア Papua New Guinea 
M7.2

2019-05-14 20:58 UTC+8
巴布亞紐幾內亞 パプアニューギニア Papua New Guinea 
M7.5

2019-05-10 07:48 UTC+8 
日本宮崎 日本宮崎 Miyazaki, Japan 
M6.1

2019-05-23 16:45 UTC+8 
阿拉斯加 アラスカ Alaska 
M6.1

2019-05-26 15:41 UTC+8 
秘魯 ペルー Peru 
M8.0

2019-05-30 17:03 UTC+8 
薩爾瓦多 エルサルバドル El Salvador 
M6.6

2019-05-31 18:12:32 UTC+8
菲律賓 フィリピン Philippines 
M6.1

2019-06-04 12:39:17 UTC+8 
日本伊豆群島 日本伊豆諸島 Izu Islands, Japan
M6.3

2019-06-04 17:46 UTC+8 
台東 台東 Taitung 
M5.6

2019-06-16 06:55 UTC+8 
紐西蘭 ニュージーランド New Zealand 
M7.2

2019-06-18 21:22 UTC+8
日本鶴岡市 日本鶴岡市 Tsuruoka, Japan 
M6.4

2019-06-24 10:53 UTC+8
印尼 インドネシア Indonesia
M7.3

2019-06-25 17:05:40 UTC+8
俄羅斯 ロシア Russia 
M6.3

2019-06-28 23:51 UTC+8
北馬里亞納群島 北マリアナ諸島 Northern Mariana Islands
M6.4

2019-06-30 03:44 UTC+8 
台東 台東 Taitung
M5.7 

2019-07-04 12:30 UTC+8
加拿大 カナダ Canada M6.2

2019-07-05 01:33 UTC+8
加州 カリフォルニア California
M6.4 

2019-07-06 11:19 UTC+8
加州 カリフォルニア California
M7.1

2019-07-07 23:08 UTC+8
印尼 インドネシア Indonesia
M6.9

2019-07-13 08:57 UTC+8
日本名瀨市 日本名瀬市 Naze, Japan
M6.1

2019-07-14 13:39 UTC+8
澳洲 オーストラリア Australia
M6.6

2019-07-14 17:10 UTC+8
印尼 インドネシア Indonesia
M7.3

2019-08-02 20:03 UTC+8
印尼 インドネシア Indonesia
M6.9

2019-08-08 05:28 UTC+8
宜蘭 宜蘭 Yilan
M6.0

2019-09-25 05:19 UTC+8
西南印度洋脊 南西インド洋海岭 Southwest Indian Ridge 
M6.1

2019-09-26 07:46 UTC+08
印尼 インドネシア Indonesia
M6.5

2019-09-27 00:36 UTC+8
阿根廷 アルゼンチン Argentina
M6.1 

2019-09-29 10:02 UTC+8
菲律賓 フィリピン Philippines
M6.2

2019-09-29 23:57 UTC+8
智利 チリ Chile
M6.8

2019-10-01 01:12 UTC+8
高雄 高雄 Kaohsiung 
M4.4

2019-10-01 01:54 UTC+8 
花蓮 花蓮 Hualien
M3.8

2019-10-12 17:21 UTC+8
日本 日本 Japan M5.3

2019-10-12 02:21 UTC-7
日本 日本 Japan M5.3

舊金山   37°48'N
東京     35°41'N
伊斯坦堡 41°01'N

2008-05-12 14:28 UTC+8
四川 四川 Sichuan M8.3

2019-10-15 13:33 UTC+8
加州 カリフォルニア California
M4.5 

2019-10-14 22:33 UTC-7
加州 カリフォルニア California
M4.5 

2019-10-16 03:42 UTC+8
加州 カリフォルニア California
M4.7

2019-10-15 12:42 UTC-7
加州 カリフォルニア California
M4.7


2019-10-16 19:37 UTC+8
菲律賓 フィリピン Philippines 
M6.4

2019-10-29 09:04 UTC+8
菲律賓 フィリピン Philippines 
M6.6

2019-10-31 09:11 UTC+8
菲律賓 フィリピン Philippines 
M6.5


2019-10-17 15:31 UTC+8 
宜蘭 宜蘭 Yilan 
M3.9

2019-10-17 19:44 UTC+8 
花蓮 花蓮 Hualien 
M5.4

2019-10-18 04:43 UTC+8
奧勒岡州 オレゴン Oregon
M4.7

2019-10-17 13:43 UTC-7
奧勒岡州 オレゴン Oregon
M4.7

2019-05-26 15:41 UTC+8 
秘魯 ペルー Peru 
M8.0

2019-07-06 11:19 UTC+8
加州 カリフォルニア California
M7.1
 
2004-12-26 00:58 UTC 印尼蘇門答臘 インドネシア、スマトラ Sumatra, Indonesia M9.1

2018-06-17 22:58 UTC 日本大阪 日本大阪 Osaka, Japan M5.5

2018-09-05 18:07 UTC 日本北海道 日本北海道 Hokkaido, Japan M6.6
 
2018-08-22 09:31 UTC 美國奧勒岡州 米国オレゴン州 Oregon, US M6.2

'''

# %%
insert_enter()
insert_Analysis_file(1)
insert_Analysis_file(2)
# Out:
# file_number: 1
# file_number: 2

# %%
IRIS signals could predict the 2018-08-22 09:31 UTC Oregon, US M6.2 quake 24 days before it happened.

2018-08-22 09:31 UTC 美國奧勒岡州 米国オレゴン州 Oregon, US M6.2

台灣地震預測研究所 所長 林湧森
台湾地震予測研究所 所長 林湧森
Dyson Lin, Founder & CEO, Taiwan Quake Forecast Institute
2019-11-08 14:06 UTC+8

# %%
name_new_files(file_number=4, to_WeChat=False, date_stamp='2019-11-09')

# %%
name_new_files(file_number=1, to_WeChat=True, date_stamp='2019-11-09')

# %%
analyze_file(1)

# %%
analyze_file(2)

# %%
analyze_file(3)

# %%
analyze_file(4)

# %%
analyze_file(5)

# %%
analyze_file(6)

# %%
insert_enter()

# %%
insert_Analysis_file(1)
# Out:
# Cannot click Blogger tab.
# ---------------------------------------------------------------------------
# FailSafeException                         Traceback (most recent call last)
# <ipython-input-7-b8b0a15738d5> in <module>
# ----> 1 insert_Analysis_file(1)
#
# <ipython-input-4-cde5b89432b0> in insert_Analysis_file(file_number)
#     302     click_Blogger_tab()
#     303     time.sleep(1)
# --> 304     click_Edit_area()
#     305     time.sleep(1)
#     306
#
# <ipython-input-4-cde5b89432b0> in click_Edit_area()
#      63 def click_Edit_area():
#      64     # click bottom of Edit area
# ---> 65     pyautogui.moveTo(1100, 1000)
#      66     #pyautogui.moveTo(1100, 1030)
#      67     #pyautogui.moveTo(1100, 1020)
#
# C:\Anaconda3\lib\site-packages\pyautogui\__init__.py in moveTo(x, y, duration, tween, pause, logScreenshot, _pause)
#     829       None
#     830     """
# --> 831     failSafeCheck()
#     832     x, y = _unpackXY(x, y)
#     833
#
# C:\Anaconda3\lib\site-packages\pyautogui\__init__.py in failSafeCheck()
#    1255 def failSafeCheck():
#    1256     if FAILSAFE and tuple(position()) in FAILSAFE_POINTS:
# -> 1257         raise FailSafeException('PyAutoGUI fail-safe triggered from mouse moving to a corner of the screen. To disable this fail-safe, set pyautogui.FAILSAFE to False. DISABLING FAIL-SAFE IS NOT RECOMMENDED.')
#    1258
#    1259
#
# FailSafeException: PyAutoGUI fail-safe triggered from mouse moving to a corner of the screen. To disable this fail-safe, set pyautogui.FAILSAFE to False. DISABLING FAIL-SAFE IS NOT RECOMMENDED.

# %%
insert_original_file(1)

# %%
# 綠

insert_files(1)
station_name = station['美國舊金山站']

languages = ['Chinese', 'Japanese', 'English']
quake_forecast = [
    {'color': Green,
     'time': 9,
     'location': {
        'Chinese': '日本東京附近，',
        'Japanese': '日本東京近郊、',
        'English': 'Near Tokyo, Japan, '},
     'magnitude': 'M8+~M9+'},
]

time_stamp = get_time_stamp()
(blog_title, blog_title_str) = publish_Quake_Forecast(quake_forecast, 
                                    station_name, languages, time_stamp)
view_blog()
# Out:
# file_number: 1
# Cannot locate:SuperBigButton.png
# Cannot locate:TitleButton.png
# Cannot locate:TitleField.png
# ---------------------------------------------------------------------------
# FailSafeException                         Traceback (most recent call last)
# <ipython-input-6-1f267914944b> in <module>
#       1 # 綠
#       2
# ----> 3 insert_files(1)
#       4 station_name = station['美國舊金山站']
#       5
#
# <ipython-input-4-cde5b89432b0> in insert_files(file_number)
#     447
#     448     for i in range(1, file_number + 1):
# --> 449         insert_original_file(i)
#     450
#     451 def set_blog_title():
#
# <ipython-input-4-cde5b89432b0> in insert_original_file(file_number)
#     387     time.sleep(1)
#     388
# --> 389     original_file_name = get_file_name(file_number, 'original')
#     390     (x, y) = get_file_location(file_number, 'original')
#     391
#
# <ipython-input-4-cde5b89432b0> in get_file_name(file_number, file_type)
#     106
#     107     (file_name_x, file_name_y) = get_file_name_location(file_number, file_type)
# --> 108     pyautogui.moveTo(file_name_x, file_name_y)
#     109     time.sleep(1)
#     110     pyautogui.click()
#
# C:\Anaconda3\lib\site-packages\pyautogui\__init__.py in moveTo(x, y, duration, tween, pause, logScreenshot, _pause)
#     829       None
#     830     """
# --> 831     failSafeCheck()
#     832     x, y = _unpackXY(x, y)
#     833
#
# C:\Anaconda3\lib\site-packages\pyautogui\__init__.py in failSafeCheck()
#    1255 def failSafeCheck():
#    1256     if FAILSAFE and tuple(position()) in FAILSAFE_POINTS:
# -> 1257         raise FailSafeException('PyAutoGUI fail-safe triggered from mouse moving to a corner of the screen. To disable this fail-safe, set pyautogui.FAILSAFE to False. DISABLING FAIL-SAFE IS NOT RECOMMENDED.')
#    1258
#    1259
#
# FailSafeException: PyAutoGUI fail-safe triggered from mouse moving to a corner of the screen. To disable this fail-safe, set pyautogui.FAILSAFE to False. DISABLING FAIL-SAFE IS NOT RECOMMENDED.

# %%
close_Blogger_article_list()
blog_address = get_blog_address()
post_Quake_Forecast(quake_forecast, 
                    station_name, time_stamp, blog_address, blog_title_str)

# %%
# 黃

insert_files(1)
station_name = station['新竹綠光站']

languages = ['Chinese', 'Japanese', 'English']
quake_forecast = [
    {'color': Yellow,
     'time': 18,
     'location': {
        'Chinese': '日本大阪附近，',
        'Japanese': '日本大阪近郊、',
        'English': 'Near Osaka, Japan, '},
     'magnitude': 'M5+~M6+'},
]

time_stamp = get_time_stamp()
(blog_title, blog_title_str) = publish_Quake_Forecast(quake_forecast, 
                                    station_name, languages, time_stamp)
view_blog()
# Out:
# file_number: 1

# %%
close_Blogger_article_list()
blog_address = get_blog_address()
post_Quake_Forecast(quake_forecast, 
                    station_name, time_stamp, blog_address, blog_title_str)

# %%
# 紅

insert_files(1)
station_name = station['花蓮吉安北站']

languages = ['Chinese', 'Japanese', 'English']
quake_forecast = [
    {'color': Red,
     'time': 2,
     'location': {
        'Chinese': '菲律賓達沃附近，',
        'Japanese': 'フィリピン、ダバオ近郊、',
        'English': 'Near Davao, Philippines, '},
     'magnitude': 'M6.4~M6.6'},
]

time_stamp = get_time_stamp()
(blog_title, blog_title_str) = publish_Quake_Forecast(quake_forecast, 
                                    station_name, languages, time_stamp)
view_blog()
# Out:
# file_number: 1

# %%
close_Blogger_article_list()
blog_address = get_blog_address()
post_Quake_Forecast(quake_forecast, 
                    station_name, time_stamp, blog_address, blog_title_str)

# %%
# 橙

insert_files(1)
station_name = station['美國舊金山站']

languages = ['Chinese', 'Japanese', 'English']
quake_forecast = [
    {'color': Orange,
     'time': 39,
     'location': {
        'Chinese': '華盛頓州、奧勒岡州或加州，',
        'Japanese': 'ワシントン、オレゴンまたはカリフォルニア、',
        'English': 'Washington, Oregon or California, '},
     'magnitude': 'M6+~M7+.'},
]

time_stamp = get_time_stamp()
(blog_title, blog_title_str) = publish_Quake_Forecast(quake_forecast, 
                                    station_name, languages, time_stamp)
view_blog()
# Out:
# file_number: 1

# %%
close_Blogger_article_list()
blog_address = get_blog_address()
post_Quake_Forecast(quake_forecast, station_name, time_stamp, blog_address, blog_title_str)
