# %%
import pyautogui
import time
import pyperclip
pyautogui.PAUSE = 0.4
pyautogui.FAILSAFE = True

def locate_and_click(png_file_name):
    try:
        # locate
        (x, y) = pyautogui.locateCenterOnScreen(png_file_name)
        
        # move mouse
        pyautogui.moveTo(x, y)
        time.sleep(1)
        
        # click
        pyautogui.click(x, y)
        time.sleep(1)
    except:
        print('Cannot locate:' + png_file_name)
    
def click_Blogger_tab():
    try:
        #locate_and_click('BloggerTab.png')
        #pyautogui.moveTo(831, 31)
        pyautogui.moveTo(770, 30)
        time.sleep(1)
        pyautogui.click()
        time.sleep(1)
    except:
        print('Cannot click Blogger tab.')
        
def click_Blog_Title():
    pyautogui.moveTo(900, 235)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)

def click_Facebook_Publish_button():
    locate_and_click('FacebookPublishButton.png')    
    
def click_Super_Big_button():
    locate_and_click('SuperBigButton.png')
    
def click_Add_Image_Title_button():
    locate_and_click('TitleButton.png')
    
def click_Add_Image_Title_field():
    locate_and_click('TitleField.png')
    
def click_Font_Size():
    pyautogui.moveTo(775, 295)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)
    
def scroll_down():
    pyautogui.moveTo(1100, 600)
    time.sleep(1)
    pyautogui.scroll(-10000) # scroll down
    time.sleep(1)
    
def click_Edit_area():    
    # click bottom of Edit area
    #pyautogui.moveTo(1100, 1000)
    pyautogui.moveTo(1100, 990)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)
    
def click_image(y):
    scroll_down()
    time.sleep(1)
    x = 700       
    pyautogui.moveTo(x, y)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)
    
def get_file_location(file_number, file_type='original'):
    if ((file_type is 'analysis') | (file_type is 'old')):
        x = 160
    else: # 'original' or 'new'
        x = 53
    
    y = 80 + (file_number - 1) * 148
    return (x, y)

def get_file_name_location(file_number, file_type='original'):
    if ((file_type is 'analysis') | (file_type is 'old')):
        x = 160
    else: # 'original' or 'new'
        x = 53
    
    y = 114 + (file_number - 1) * 148
    return (x, y)

def get_file_name(file_number, file_type='original'):
    (file_x, file_y) = get_file_location(file_number, file_type)
    pyautogui.moveTo(file_x, file_y)
    time.sleep(1)
    #time.sleep(0.5)
    pyautogui.click()
    time.sleep(1)

    (file_name_x, file_name_y) = get_file_name_location(file_number, file_type)
    pyautogui.moveTo(file_name_x, file_name_y)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)
    
    pyautogui.rightClick()
    for i in range(3):
        pyautogui.press('down')
        
    pyautogui.press('c') # copy file name to clipboard
    time.sleep(0.5)
    
    file_name = pyperclip.paste() # read file name from clipboard
    return file_name

def duplicate_file():
    pyautogui.rightClick()
    time.sleep(1)
    for i in range(5):
        pyautogui.press('up')
    pyautogui.press('c')
    
    pyautogui.moveRel(100, 0)
    pyautogui.rightClick()
    for i in range(4):
        pyautogui.press('down')
    pyautogui.press('p')
    time.sleep(1)
    
# Ramane file_name to file_name - Analysis
def rename_file():
    pyautogui.click()
    time.sleep(1)
    pyautogui.moveRel(0, 34)
    pyautogui.click()
    time.sleep(1)
    pyautogui.press('end')
    for i in range(4):
        pyautogui.press('left')
    for i in range(2):
        pyautogui.press('backspace')
    pyautogui.typewrite('Analysis')
    pyautogui.press('enter')
    
# Open file with Painter
def open_file():
    pyautogui.doubleClick()
    #time.sleep(7)
    time.sleep(3)
    
    # select Rectangle
    #pyautogui.moveTo(445, 65)
    pyautogui.moveTo(464, 67)
    pyautogui.click() 
    
    # select Red
    #pyautogui.moveTo(814, 62)
    
    # select Green
    #pyautogui.moveTo(880, 62)
    
    # select Purple
    #pyautogui.moveTo(946, 62)
    
    # select Yellow
    pyautogui.moveTo(858, 62)
    
    pyautogui.click() 
    
# Duplicate file, ramane it and open it with Painter
def analyze_file(file_number):
    (x, y) = get_file_location(file_number, 'original')
    pyautogui.moveTo(x, y)
    duplicate_file()
    rename_file()
    open_file()

def get_date_stamp():
    date_stamp = time.strftime("%Y-%m-%d")
    return date_stamp

def get_time_stamp():
    time_stamp = time.strftime("%Y-%m-%d")
    time_stamp += ' '
    time_stamp += time.strftime("%H:%M")
    time_stamp += ' UTC+8'
    return time_stamp

def get_new_file_name(old_file_name, date_stamp):
    splt_old_file_name = old_file_name.split()
    old_date_stamp = splt_old_file_name[0]
    old_date = old_date_stamp[0:10]
    
    if date_stamp is None:
        new_date_stamp = get_date_stamp()
    else:
        new_date_stamp = date_stamp
    
    new_date = new_date_stamp[0:10]
    
    if (new_date == old_date):
        new_date_stamp = new_date + '-2'
  
    new_file_name = old_file_name.replace(old_date_stamp, new_date_stamp)
    #print('New file name: ' + new_file_name)
  
    return new_file_name

def name_file(file_number, new_file_name):
    (x, y) = get_file_location(file_number, 'new')
    pyperclip.copy(new_file_name) # copy new file name to clipboard
    pyautogui.moveTo(x, y)
    time.sleep(0.5)
    pyautogui.click()
    time.sleep(1)
    
    (x, y) = get_file_name_location(file_number, 'new')
    pyautogui.moveTo(x, y)
    time.sleep(0.5)
    pyautogui.click()
    time.sleep(1)
  
    pyautogui.rightClick()
    time.sleep(1)
    for i in range(4):
        pyautogui.press('down')
        #time.sleep(0.5)
    pyautogui.press('p') # paste new file name from clip board
    time.sleep(1)
    pyautogui.press('enter')

def click_WeChat_icon():
    pyautogui.moveTo(1500, 1079)
    time.sleep(1)
    #pyautogui.moveTo(564, 1058)
    pyautogui.moveTo(613, 1060)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)

def click_WeChat_Edit_area():
    pyautogui.moveTo(1090, 935)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)
    
# Paste a file's name to WeChat and then drag it to WeChat
def drag_to_WeChat(file_number, file_type='original'):
    # copy file name to clipboard
    get_file_name(file_number, file_type)
    
    click_WeChat_icon()
    click_WeChat_Edit_area()

    # paste file name from clipboard
    pyautogui.hotkey('ctrl', 'v')

    (x, y) = get_file_location(file_number, file_type)
    pyautogui.moveTo(x, y)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)
    
    pyautogui.dragTo(1090, 935, 2)
    pyautogui.click()
    time.sleep(1)

    pyautogui.press('enter')    
    
    time.sleep(1)
    click_WeChat_icon()
    
def name_new_file(file_number, date_stamp):
    old_file_name = get_file_name(file_number, 'old')
    time.sleep(1)
    new_file_name = get_new_file_name(old_file_name, date_stamp)
    time.sleep(1)
    name_file(file_number, new_file_name)

def name_new_files(file_number=1, to_WeChat=False, date_stamp=None):
    for i in range(file_number):
        name_new_file(i+1, date_stamp)
        
    if to_WeChat:
        for i in range(file_number):
            drag_to_WeChat(i+1)

def insert_enter():
    click_Blogger_tab()
    time.sleep(1)
    click_Edit_area()
    time.sleep(1)
    
    pyautogui.press('enter')
    time.sleep(1)
    
            
def insert_Analysis_file(file_number):    
    click_Blogger_tab()
    time.sleep(1)
    click_Edit_area()
    time.sleep(1)
    
    #print('file_number:', file_number)
    
    pyautogui.press('up')
    time.sleep(1)
    
    analysis_file_name = get_file_name(file_number, 'analysis')    
    (x, y) = get_file_location(file_number, 'analysis')
    
    pyautogui.moveTo(x, y)
    time.sleep(0.5)
    pyautogui.click()
    time.sleep(0.5)
    
    if (file_number == 1):
        (x, y) = (700, 400)
        pyautogui.dragTo(x, y, 2)
    else:
        (x, y) = (700, 957)
        #(x, y) = (700, 977)
        pyautogui.dragTo(x, y, 2)
    
    #time.sleep(7)
    #time.sleep(6)
    time.sleep(15)

    scroll_down()

    click_Edit_area()
    
    if (file_number == 1):
        click_image(500)
    else:
        click_image(957)
        #click_image(977)
        
    scroll_down()
    
    click_Super_Big_button()
    scroll_down()
    
    click_Add_Image_Title_button()
    time.sleep(1)
    scroll_down()
    time.sleep(1)
    
    click_Add_Image_Title_field()
    time.sleep(1)
    pyautogui.tripleClick()
    time.sleep(1)
    
    # paste file name from clipboard
    pyautogui.hotkey('ctrl', 'v')
    time.sleep(1)
    
    click_Font_Size()

    pyautogui.moveRel(0, 93)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)

    scroll_down()
    time.sleep(1)
    
    click_Edit_area()
    time.sleep(1)
    
    pyautogui.press('up')
    time.sleep(1)

def insert_original_file(file_number):
    click_Blogger_tab()
    time.sleep(1)
    click_Edit_area()
    time.sleep(1)
    pyautogui.press('up')
    time.sleep(1)
    
    original_file_name = get_file_name(file_number, 'original')
    (x, y) = get_file_location(file_number, 'original')
    
    pyautogui.moveTo(x, y)
    time.sleep(0.5)
    pyautogui.click()
    time.sleep(0.5)
    
    pyautogui.dragTo(700, 957, 2)
    #time.sleep(7)
    #time.sleep(6)
    time.sleep(15)
    
    scroll_down()
    
    click_Edit_area()
    time.sleep(1)
    click_image(957)
    time.sleep(1)
    scroll_down()   
    
    click_Super_Big_button()
    time.sleep(1)
    scroll_down()
    
    click_Add_Image_Title_button()
    time.sleep(1)
    scroll_down()
    
    click_Add_Image_Title_field()
    time.sleep(1)
    pyautogui.tripleClick()
    time.sleep(1)
    
    # paste file name from clipboard
    pyautogui.hotkey('ctrl', 'v')
    time.sleep(1)
    
    click_Font_Size()
    time.sleep(1)

    pyautogui.moveRel(0, 93)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)

    scroll_down()
    time.sleep(1)
    click_Edit_area()
    time.sleep(1)
    pyautogui.press('up')
    time.sleep(1)

def insert_files(file_number=1):
    insert_enter()
    
    for i in range(1, file_number + 1):
        insert_Analysis_file(i)
        
    for i in range(1, file_number + 1):
        insert_original_file(i)

def set_blog_title():
    click_Blogger_tab()
    click_Blog_Title()
    
    # paste from clipboard
    pyautogui.rightClick()
    pyautogui.press('down')
    pyautogui.press('down')
    pyautogui.press('p')
    pyautogui.press('enter')

def get_Quake_Forecast_title(quake_forecast, station_name, languages, time_stamp):
    blog_title = {}
    for language in languages:
        blog_title[language] = station_name[language]
        blog_title[language] += quake_forecast_title[language]
        quake_number = 0
        for quake in quake_forecast:
            quake_number += 1
            blog_title[language] += '('
            blog_title[language] += str(quake_number)
            blog_title[language] += ')'
            blog_title[language] += quake['color'][language]
            blog_title[language] += Within[language]
            blog_title[language] += str(quake['time'])
            blog_title[language] += Days[language]
            blog_title[language] += quake['location'][language]
            blog_title[language] += quake['magnitude']
            blog_title[language] += ' '
    
    blog_title_str = (time_stamp + ' ')
    
    for language in languages:
        blog_title_str += (blog_title[language])
    
    blog_title_str = blog_title_str.strip() # remove extra white space
    #print(blog_title_str)
    pyperclip.copy(blog_title_str) # copy to clipboard
    
    return (blog_title, blog_title_str)

def get_Quake_Forecast_text(quake_forecast, station_name, languages, time_stamp):
    blog_text = {}
    for language in languages:
        blog_text[language] = station_name[language]
        blog_text[language] += quake_forecast_title[language] + '\n'
        quake_number = 0
        for quake in quake_forecast:
            quake_number += 1
            blog_text[language] += '('
            blog_text[language] += str(quake_number)
            blog_text[language] += ')'
            blog_text[language] += quake['color'][language]
            blog_text[language] += Within[language]
            blog_text[language] += str(quake['time'])
            blog_text[language] += Days[language]
            blog_text[language] += quake['location'][language]
            blog_text[language] += quake['magnitude']
            blog_text[language] += '\n'
        blog_text[language] += '\n'    
        blog_text[language] += author[language]
        blog_text[language] += '\n'
        blog_text[language] += time_stamp
        blog_text[language] += '\n\n\n'

    blog_text_str = ''        
    for language in languages:
        blog_text_str += blog_text[language]
    blog_text_str = blog_text_str.strip() # remove extra white space
    #print(blog_text_str)
    pyperclip.copy(blog_text_str) # copy to clipboard
    
def get_Quake_Signals_title(signals, station_name, languages, time_stamp): 
    blog_title = {}
    for language in languages:
        blog_title[language] = station_name[language]
        blog_title[language] += quake_signals_title[language]
        blog_title[language] += Already_happened[language]
        quake_number = 0
        for quake in signals:
            quake_number += 1
            blog_title[language] += '('
            blog_title[language] += str(quake_number)
            blog_title[language] += ')'
            blog_title[language] += quake['color'][language]
            #blog_title[language] += Within[language]
            blog_title[language] += str(quake['time'])
            blog_title[language] += ' '
            blog_title[language] += quake['location'][language]
            blog_title[language] += ' '
            blog_title[language] += quake['magnitude']
            blog_title[language] += ' '
    
    blog_title_str = (time_stamp + ' ')
    
    for language in languages:
        blog_title_str += (blog_title[language])
    
    blog_title_str = blog_title_str.strip() # remove extra white space
    #print(blog_title_str)
    pyperclip.copy(blog_title_str) # copy to clipboard
    
    return (blog_title, blog_title_str)

def get_Quake_Signals_text(signals, station_name, languages, time_stamp):
    blog_text = {}
    for language in languages:
        blog_text[language] = station_name[language]
        blog_text[language] += quake_signals_title[language] + '\n'
        blog_text[language] += Already_happened[language] + '\n'
        quake_number = 0
        for quake in signals:
            quake_number += 1
            blog_text[language] += '('
            blog_text[language] += str(quake_number)
            blog_text[language] += ')'
            blog_text[language] += quake['color'][language]
            #blog_text[language] += Within[language]
            blog_text[language] += str(quake['time'])
            blog_text[language] += ' '
            #blog_text[language] += Days[language]
            blog_text[language] += quake['location'][language]
            blog_text[language] += ' '
            blog_text[language] += quake['magnitude']
            blog_text[language] += '\n'
        blog_text[language] += '\n'    
        blog_text[language] += author[language]
        blog_text[language] += '\n'
        blog_text[language] += time_stamp
        blog_text[language] += '\n\n\n'

    blog_text_str = ''        
    for language in languages:
        blog_text_str += blog_text[language]
    blog_text_str = blog_text_str.strip() # remove extra white space
    #print(blog_text_str)
    pyperclip.copy(blog_text_str) # copy to clipboard
    
def get_blog_address():
    click_Blogger_tab()

    pyautogui.moveTo(710, 61)
    time.sleep(1)
    #pyautogui.tripleClick()
    pyautogui.click() # click
    #time.sleep(0.1)
    pyautogui.click() # click
    #time.sleep(0.1)
    pyautogui.click() # click
    #time.sleep(0.1)
    
    pyautogui.rightClick()
    pyautogui.press('down')
    pyautogui.press('down')
    pyautogui.press('c') # copy blog address to clipboard
    blog_address = pyperclip.paste() # read blog address from clipboard
    return blog_address

def set_blog_text():
    click_Blogger_tab()
    scroll_down()
    click_Edit_area()
    pyautogui.press('backspace')

    pyautogui.hotkey('ctrl', 'v') # paste from clipboard
    #pyautogui.rightClick()
    #pyautogui.press('down')
    #pyautogui.press('down')
    #pyautogui.press('p') # paste from clipboard
    
def click_Facebook_tab(tab_number):
    global Facebook_tab_1_x
    global Facebook_tab_2_x
    global Facebook_tab_3_x
    
    if tab_number is 1:
        (x, y) = (475, 30)
    elif tab_number is 2:
        (x, y) = (590, 30)
    elif tab_number is 3:
        (x, y) = (700, 30)
    else:
        print('Wrong tab number:', str(tab_number))
    
    pyautogui.moveTo(x, y)
    time.sleep(1)
    pyautogui.click() # click
    
def click_WeChat_icon():
    #pyautogui.moveTo(1000, 1079)
    pyautogui.moveTo(613, 1079)
    time.sleep(1)
    #pyautogui.moveTo(564, 1058)
    pyautogui.moveTo(613, 1060)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)
    
def click_WeChat_Edit_area():
    pyautogui.moveTo(1090, 935)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)
    
def post_to_WeChat():
    click_WeChat_icon()
    click_WeChat_Edit_area()
    
    # paste Quake Forecast from clipboard
    pyautogui.hotkey('ctrl', 'v')
    
    # darg analysis file 1 to WeChat
    x = 160
    y = 70
    pyautogui.moveTo(x, y)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)
    
    pyautogui.dragTo(1090, 935, 2)
    pyautogui.click()
    time.sleep(1)

    pyautogui.press('enter')
    time.sleep(3)
    click_WeChat_icon()
    time.sleep(1)
    
def click_Twitter_tab():
    (x, y) = (360, 30)
    pyautogui.moveTo(x, y)
    time.sleep(1)
    pyautogui.click() # click
    time.sleep(1)
    
def click_Twit_button():
    (x, y) = (455, 999)
    pyautogui.moveTo(x, y)
    time.sleep(1)
    pyautogui.click() # click
    time.sleep(1)

def click_Twitter_Edit_area():
    (x, y) = (1100, 350)
    pyautogui.moveTo(x, y)
    time.sleep(1)
    pyautogui.click() # click
    time.sleep(1)

def post_to_Twitter():
    click_Twitter_tab()
    click_Twit_button()
    click_Twitter_Edit_area()

    # paste Quake Forecast from clipboard
    pyautogui.hotkey('ctrl', 'v')
    time.sleep(1)
    
    # darg analysis file 1 to Twitter
    x = 160
    y = 70
    pyautogui.moveTo(x, y)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)
    
    pyautogui.dragTo(1100, 350, 2)
    pyautogui.click()
    time.sleep(1)

    for i in range(0, 8):
        pyautogui.press('tab')
        time.sleep(1)
    pyautogui.press('enter')
    
    time.sleep(3)
    
    #pyautogui.scroll(-100) # scroll down

def publish_blog():
    #pyautogui.moveTo(1717, 237)
    pyautogui.moveTo(1715, 219)
    time.sleep(5)
    pyautogui.click()
    #time.sleep(5)
    time.sleep(1)
    
def view_blog():
    click_Blogger_tab()
    time.sleep(1)
    pyautogui.moveTo(833, 504)
    #pyautogui.moveTo(833, 524)
    time.sleep(1)
    pyautogui.moveTo(833, 506)
    #pyautogui.moveTo(833, 526)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)

def close_Blogger_article_list():
    click_Blogger_tab()
    time.sleep(1)
    
    pyautogui.click()
    time.sleep(1)
    
    pyautogui.rightClick()
    time.sleep(1)

    for i in range(0, 7):
        pyautogui.press('down')
    
    time.sleep(1)
    pyautogui.press('enter')

    pyautogui.moveRel(80, 0)
    time.sleep(2)
    
def post_Quake_Forecast(quake_forecast, station_name, time_stamp,
            blog_address, blog_title_str):
    # Post to Twitter, WeChat and Facebook.

    #Twitter_languages = ['Chinese']
    #(blog_title_Twitter, blog_title_str_Twitter) = get_Quake_Forecast_title(quake_forecast,
    #                                            station_name, Twitter_languages, time_stamp)
    #post_text_Twitter = blog_title_str_Twitter + '\n' + blog_address
    #pyperclip.copy(post_text_Twitter) # copy to clipboard
    #post_to_Twitter()

    #Twitter_languages = ['Japanese']
    #(blog_title_Twitter, blog_title_str_Twitter) = get_Quake_Forecast_title(quake_forecast,
    #                                            station_name, Twitter_languages, time_stamp)
    #post_text_Twitter = blog_title_str_Twitter + '\n' + blog_address
    #pyperclip.copy(post_text_Twitter) # copy to clipboard
    #post_to_Twitter()

    Twitter_languages = ['English']
    (blog_title_Twitter, blog_title_str_Twitter) = get_Quake_Forecast_title(quake_forecast,
                                                station_name, Twitter_languages, time_stamp)
    post_text_Twitter = blog_title_str_Twitter + '\n' + blog_address
    pyperclip.copy(post_text_Twitter) # copy to clipboard
    post_to_Twitter()
    
    
    post_text = blog_title_str + '\n' + blog_address    
    pyperclip.copy(post_text) # copy to clipboard
    post_to_WeChat()

    pyperclip.copy(post_text) # copy to clipboard
    post_to_Facebook(1)

    pyperclip.copy(post_text) # copy to clipboard
    post_to_Facebook(2)

    pyperclip.copy(post_text) # copy to clipboard
    post_to_Facebook(3)

def publish_Quake_Forecast(quake_forecast, station_name, languages, time_stamp):
    (blog_title, blog_title_str) = get_Quake_Forecast_title(quake_forecast, 
                                          station_name, languages, time_stamp)
    set_blog_title()
    get_Quake_Forecast_text(quake_forecast, station_name, languages, time_stamp)
    set_blog_text()
    publish_blog()
    time.sleep(15)
    return (blog_title, blog_title_str)    

def post_to_Facebook(tab_number):
    click_Facebook_tab(tab_number)
    
    # click Post field
    if tab_number is 1:
        (x, y) = (1244, 945)
        pyautogui.moveTo(x, y)
        time.sleep(1)
        pyautogui.scroll(10000) # scroll up
        time.sleep(1)
    elif tab_number is 2:
        (x, y) = (720, 980)
        pyautogui.moveTo(x, y)
        time.sleep(1)
        pyautogui.scroll(10000) # scroll up
        time.sleep(1) 
    elif tab_number is 3:
        #(x, y) = (780, 950)
        (x, y) = (760, 1035)
        pyautogui.moveTo(x, y)
        time.sleep(1)
        pyautogui.scroll(10000) # scroll up
        time.sleep(1)
        pyautogui.scroll(-100) # scroll down
        time.sleep(1)
    else:
        print('Wrong tab number:', str(tab_number))
        
    pyautogui.moveTo(x, y)
    time.sleep(1)
    pyautogui.click()
    time.sleep(1)

    # paste Quake Forecast from clipboard
    pyautogui.hotkey('ctrl', 'v')
    time.sleep(4)
    
    if tab_number is 1:
        pyautogui.moveTo(x+100, y)
        time.sleep(1)
        pyautogui.scroll(-700) # scroll down
        time.sleep(2)
        
        for i in range(0, 14):
            pyautogui.press('tab')
            time.sleep(1)
        pyautogui.press('enter')
        time.sleep(1)
    elif tab_number is 2:
        pyautogui.moveTo(x+100, y)
        time.sleep(1)
        pyautogui.scroll(-700) # scroll down
        time.sleep(2)
        
        for i in range(0, 17):
            pyautogui.press('tab')
            time.sleep(1)
        pyautogui.press('enter')
        time.sleep(1)
    elif tab_number is 3:
        for i in range(0, 27):
            pyautogui.press('tab')
            time.sleep(1)
        pyautogui.press('enter')
        time.sleep(1)
    else:
        print('Wrong tab number:', str(tab_number))
    
    time.sleep(1)
    
quake_forecast_title = {
    'Chinese': '地震預報：',
    'Japanese': '地震予報：',
    'English': 'Quake Forecast: '
}

quake_signals_title = {
    'Chinese': '地震訊號：',
    'Japanese': '地震信号：',
    'English': 'Quake Signals: '
}

author = {
    'Chinese': '台灣地震預測研究所 所長\n林湧森',
    'Japanese': '台湾地震予測研究所 所長\n林湧森',
    'English': 'Dyson Lin\nFounder & CEO, Taiwan Quake Forecast Institute'}

Already_happened = {
    'Chinese': '已經發生：',
    'Japanese': '発生しました：',
    'English': 'Already happened: '}

Within = {
    'Chinese': '',
    'Japanese': '',
    'English': 'Within '}

Days = {
    'Chinese': '天以內，',
    'Japanese': '日間以內に、',
    'English': ' days, '}

Red = {
    'Chinese': '紅：',
    'Japanese': '赤：',
    'English': 'Red: '}

Orange = {
    'Chinese': '橙：',
    'Japanese': 'オレンジ：',
    'English': 'Orange: '}

Yellow = {
    'Chinese': '黃：',
    'Japanese': '黃：',
    'English': 'Yellow: '}

Green = {
    'Chinese': '綠：',
    'Japanese': '綠：',
    'English': 'Green: '}

Blue = {
    'Chinese': '藍：',
    'Japanese': '青：',
    'English': 'Blue: '}

Purple = {
    'Chinese': '紫：',
    'Japanese': '紫：',
    'English': 'Purple: '}



station = {}

station['台灣各站'] = {
    'Chinese': '台灣各站', 
    'Japanese': '台湾各局', 
    'English': 'Taiwan Stations '}

station['宜蘭站'] = {
    'Chinese': '宜蘭站', 
    'Japanese': '宜蘭局', 
    'English': 'Yilan Station '}

station['上海站'] = {
    'Chinese': '上海站', 
    'Japanese': '上海局', 
    'English': 'Shanghai Station '}

station['洛杉磯站'] = {
    'Chinese': '洛杉磯站', 
    'Japanese': 'ロサンゼルス局', 
    'English': 'Los Angeles Station '}

station['新竹綠光站'] = {
    'Chinese': '新竹綠光站', 
    'Japanese': '新竹綠光局', 
    'English': 'Hsinchu Green Light Station '}

station['南投草屯站'] = {
    'Chinese': '南投草屯站', 
    'Japanese': '南投草屯局', 
    'English': 'Nantou Caotun Station '}

station['台南熱心站'] = {
    'Chinese': '台南熱心站', 
    'Japanese': '台南熱心局', 
    'English': 'Tainan Hot Heart Station '}

station['台南喜福站'] = {
    'Chinese': '台南喜福站', 
    'Japanese': '台南喜福局', 
    'English': 'Tainan Joy & Luck Station '}

station['台南新生站'] = {
    'Chinese': '台南新生站', 
    'Japanese': '台南新生局', 
    'English': 'Tainan Xinsheng Station '}

station['桃園龜山站'] = {
    'Chinese': '桃園龜山站', 
    'Japanese': '桃園亀山局', 
    'English': 'Taoyuan Guishan Station '}

station['台中大里站'] = {
    'Chinese': '台中大里站', 
    'Japanese': '台中大里局', 
    'English': 'Taichung Dali Station '}

station['南非德本站'] = {
    'Chinese': '南非德本站', 
    'Japanese': '南アフリカ ダーバン局', 
    'English': 'Durban, South Africa Station '}

station['義大利法恩扎站'] = {
    'Chinese': '義大利法恩扎站', 
    'Japanese': 'イタリア ファエンツァ局', 
    'English': 'Faenza, Italy Station '}

station['義大利卡爾塔尼塞塔站'] = {
    'Chinese': '義大利卡爾塔尼塞塔站', 
    'Japanese': 'イタリア カルタニッセッタ局', 
    'English': 'Caltanissetta, Italy Station '}

station['紐西蘭奧克蘭站'] = {
    'Chinese': '紐西蘭奧克蘭站', 
    'Japanese': 'ニュージーランド オークランド局', 
    'English': 'Auckland, New Zealand Station '}

station['智利伊基克站'] = {
    'Chinese': '智利伊基克站', 
    'Japanese': 'チリ イキケ局', 
    'English': 'Iquique, Chile Station '}

station['加拿大列治文站'] = {
    'Chinese': '加拿大列治文站', 
    'Japanese': 'カナダ リッチモンド局', 
    'English': 'Richmond BC Canada Station '}

station['嘉義站'] = {
    'Chinese': '嘉義站', 
    'Japanese': '嘉義局', 
    'English': 'Chiayi Station '}

station['日本輻射值'] = {
    'Chinese': '日本輻射值', 
    'Japanese': '日本の放射線値', 
    'English': 'Japan Radiation Value '}

station['高雄前鎮站'] = {
    'Chinese': '高雄前鎮站', 
    'Japanese': '高雄前鎮局', 
    'English': 'Kaohsiung Cianjhen Station '}

station['高雄前鎮南站'] = {
    'Chinese': '高雄前鎮南站', 
    'Japanese': '高雄前鎮南局', 
    'English': 'Kaohsiung Cianjhen South Station '}

station['高雄小港站'] = {
    'Chinese': '高雄小港站', 
    'Japanese': '高雄小港局', 
    'English': 'Kaohsiung Xiaogang Station '}

station['智利聖地牙哥站'] = {
    'Chinese': '智利聖地牙哥站', 
    'Japanese': 'チリ サンディエゴ局', 
    'English': 'Santiago, Chile Station '}

station['屏東站'] = {
    'Chinese': '屏東站', 
    'Japanese': '屏東局', 
    'English': 'Pingtung Station '}

station['成都站'] = {
    'Chinese': '成都站', 
    'Japanese': '成都局', 
    'English': 'Chengdu Station '}

station['蘇州站'] = {
    'Chinese': '蘇州站', 
    'Japanese': '蘇州局', 
    'English': 'Suzhou Station '}

station['彰化站'] = {
    'Chinese': '彰化站', 
    'Japanese': '彰化局', 
    'English': 'Changhua Station '}

station['台中北區站'] = {
    'Chinese': '台中北區站', 
    'Japanese': '台中北區局', 
    'English': 'Taichung North Station '}

station['台南安南站'] = {
    'Chinese': '台南安南站', 
    'Japanese': '台南安南局', 
    'English': 'Tainan Annan Station '}

station['日本宇都宮站'] = {
    'Chinese': '日本宇都宮站', 
    'Japanese': '日本宇都宮局', 
    'English': 'Utsunomiya, Japan Station '}

station['日本東京站'] = {
    'Chinese': '日本東京站', 
    'Japanese': '日本東京局', 
    'English': 'Tokyo, Japan Station '}

station['新北站'] = {
    'Chinese': '新北站', 
    'Japanese': '新北局', 
    'English': 'New Taipei Station '}

station['台南東區站'] = {
    'Chinese': '台南東區站', 
    'Japanese': '台南東區局', 
    'English': 'Tainan East Station '}

station['花蓮吉安北站'] = {
    'Chinese': '花蓮吉安北站', 
    'Japanese': '花蓮吉安北局', 
    'English': 'Hualien Jian North Station '}

station['台北站'] = {
    'Chinese': '台北站', 
    'Japanese': '台北局', 
    'English': 'Taipei Station '}

station['竹北豆子埔公園站'] = {
    'Chinese': '竹北豆子埔公園站', 
    'Japanese': '竹北豆子埔公園局', 
    'English': 'Zhubei Douzipu Park Station '}

station['台東站'] = {
    'Chinese': '台東站', 
    'Japanese': '台東局', 
    'English': 'Taitung Station '}

station['桃園平鎮站'] = {
    'Chinese': '桃園平鎮站', 
    'Japanese': '桃園平鎮局', 
    'English': 'Taoyuan Pingzhen Station '}

station['桃園龍潭站'] = {
    'Chinese': '桃園龍潭站', 
    'Japanese': '桃園龍潭局', 
    'English': 'Taoyuan Longtan Station '}

station['基隆安樂站'] = {
    'Chinese': '基隆安樂站', 
    'Japanese': '基隆安樂局', 
    'English': 'Keelung Anle Station '}

station['花蓮站'] = {
    'Chinese': '花蓮站', 
    'Japanese': '花蓮局', 
    'English': 'Hualien Station '}

station['花蓮玉里站'] = {
    'Chinese': '花蓮玉里站', 
    'Japanese': '花蓮玉里局', 
    'English': 'Hualien Yuli Station '}

station['美國舊金山站'] = {
    'Chinese': '美國舊金山站', 
    'Japanese': '米国サンフランシスコ局', 
    'English': 'San Francisco, US Station '}

station['高雄大樹站'] = {
    'Chinese': '高雄大樹站', 
    'Japanese': '高雄大樹局', 
    'English': 'Kaohsiung Dashu Station '}

station['桃園山仔頂站'] = {
    'Chinese': '桃園山仔頂站', 
    'Japanese': '桃園山仔頂局', 
    'English': 'Taoyuan Shanziding Station '}

station['日本宮古島站'] = {
    'Chinese': '日本宮古島站', 
    'Japanese': '日本宮古島局', 
    'English': 'Miyako, Japan Station '}

station['花蓮吉安南站'] = {
    'Chinese': '花蓮吉安南站', 
    'Japanese': '花蓮吉安南局', 
    'English': 'Hualien Jian South Station '}

station['印度西里古里站'] = {
    'Chinese': '印度西里古里站', 
    'Japanese': 'インド シリグリ局', 
    'English': 'Siliguri, India Station '}

station['土耳其伊斯坦堡彭迪克站'] = {
    'Chinese': '土耳其伊斯坦堡彭迪克站', 
    'Japanese': 'トルコ イスタンブール ペンディク局', 
    'English': 'Istanbul Pendik, Turkey Station '}

station['美國聖地牙哥站'] = {
    'Chinese': '美國聖地牙哥站', 
    'Japanese': '米国サンディエゴ局', 
    'English': 'San Diego, US Station '}

station['義大利馬切拉塔站'] = {
    'Chinese': '義大利馬切拉塔站', 
    'Japanese': 'イタリア マチェラータ局', 
    'English': 'Macerata, Italy Station '}

station['土耳其伊斯坦堡庫科切梅切站'] = {
    'Chinese': '土耳其伊斯坦堡庫科切梅切站', 
    'Japanese': 'トルコ イスタンブール クチュクチェクメツェ局', 
    'English': 'Istanbul Kucukcekmece, Turkey Station '}

station['墨西哥特拉斯卡拉站'] = {
    'Chinese': '墨西哥特拉斯卡拉站', 
    'Japanese': 'メキシコ トラスカラ局', 
    'English': 'Tlaxcala, Mexico Station '}

station['日本大阪站'] = {
    'Chinese': '日本大阪站', 
    'Japanese': '日本大阪局', 
    'English': 'Osaka, Japan Station '}

# %%
insert_enter()
insert_Analysis_file(1)
insert_Analysis_file(2)
#insert_Analysis_file(3)
#insert_Analysis_file(4)

# %%
日本大阪站開始運轉。
可喜可賀。

日本大阪局が稼動を開始しました。
喜ばしいです。

Osaka, Japan Station has started running.
Congratulations.

台灣地震預測研究所 所長 林湧森
台湾地震予測研究所 所長 林湧森
Dyson Lin, Founder & CEO, Taiwan Quake Forecast Institute
2019-12-26 20:52 UTC+8

# %%
2017-09-08 04:49 UTC 墨西哥 メキシコ Mexico M8.2
2018-09-06 15:49 UTC 斐濟 フィジー Fiji M7.9

2019-05-26 07:41 UTC 秘魯 ペルー Peru M8.0
2019-07-06 03:19 UTC 加州 カリフォルニア California M7.1

2019-11-06 07:40 UTC 伊朗 イラン Iran M5.3
2019-11-07 22:47 UTC 伊朗 イラン Iran M5.9
    
IRIS JKA-JP Station 
2019-11-10 10:46 UTC 40.256°N 144.023°E Miyako, Japan M5.2


2019-08-07 21:28 UTC 台灣宜蘭 台湾宜蘭 Yilan, Taiwan M5.8
        

2019-09-19 07:06 UTC 印尼 インドネシア Indonesia M6.1
2019-09-25 23:46 UTC 印尼 インドネシア Indonesia M6.5
2019-09-29 02:02 UTC 菲律賓 フィリピン Philippines M6.2
        
2019-10-16 11:37 UTC 菲律賓 フィリピン Philippines M6.4
2019-10-29 01:04 UTC 菲律賓 フィリピン Philippines M6.6
2019-10-31 01:11 UTC 菲律賓 フィリピン Philippines M6.5
2019-11-14 16:17 UTC 印尼 インドネシア Indonesia M7.1
2019-11-20 23:50 UTC 寮國 ラオス Laos M6.1
2019-11-23 12:11 UTC 印尼 インドネシア Indonesia M6.1
2019-12-15 06:11 UTC 菲律賓 フィリピン Philippines M6.9
2019-12-16 11:25 UTC 台灣宜蘭 台湾宜蘭 Yilan, Taiwan M4.9

2019-11-20 04:27 UTC 墨西哥 メキシコ Mexico M6.3
2019-11-20 08:26 UTC 俄羅斯 ロシア Russia M6.3
    
2019-11-24 00:54 UTC 阿拉斯加 アラスカ Alaska M6.3
2019-11-25 01:32 UTC 台灣花蓮 台湾花蓮 Hualian, Taiwan M5.0

2019-11-26 02:54 UTC 阿爾巴尼亞 アルバニア Albania M6.4
2019-11-27 07:23 UTC 希臘 ギリシャ Greece M6.0 
    
2019-11-30 07:44 UTC 瓜地馬拉 グアテマラ Guatemala M5.6

2019-07-06 03:19 UTC 加州 カリフォルニア California M7.1
    
2019-12-23 20:56 UTC 加拿大 カナダ Canada M6.0
2019-12-24 19:03 UTC 哥倫比亞 コロンビア Colombia M6.0
2019-12-25 03:36 UTC 加拿大 カナダ Canada M6.3

2019-12-10 20:14 UTC 土耳其 トルコ Turkey M4.7
2019-12-27 07:02 UTC 土耳其埃拉澤 トルコ エラズー Elazığ, Turkey M5.1

2019-12-29 09:12 UTC 菲律賓 フィリピン Philippines M5.2

2019-12-16 11:25 UTC 宜蘭 宜蘭 Yilan M5.0
    
2019-12-31 13:09 UTC 台東 台東 Taitung M3.4
    
2020-01-01 03:10 UTC 花蓮 花蓮 Hualien M4.8

# %%
2018-06-17 22:58 UTC 日本 日本 Japan M5.5

# %%
2019-08-29 15:07 UTC 奧勒岡 オレゴン Oregon M6.3

# %%
1999-09-20 17:47 UTC 台灣 台湾 Taiwan M7.7

# %%
IRIS signals could predict the 2019-09-26 10:59 UTC 土耳其西利布里亞 トルコ シリヴリ Silivri, Turkey M5.7 quake 12 days before it happened.

2019-09-26 10:59 UTC 土耳其西利布里亞 トルコ シリヴリ Silivri, Turkey M5.7

# %%
2019-11-07 22:47 UTC 伊朗 イラン Iran M5.9
2019-11-29 17:20 UTC 伊朗 イラン Iran M5.0

# %%
M5.2 - 130km W of Brookings, OR
2019-10-28 11:01:04 (UTC

# %%
2019-12-10 20:14 UTC 土耳其 トルコ Turkey M4.7
2019-12-10 17:05 UTC 日本 日本 Japan M5.9

# %%
2019-12-22 19:03 UTC 花蓮 花蓮 Hualien M4.0

# %%
insert_files(1)

# %%
花蓮吉安北站地震訊號：
(1)橙：2019-12-15 06:11 UTC 菲律賓 M6.9
(2)紫：2019-12-16 11:25 UTC 台灣宜蘭 M4.9

花蓮吉安北局地震信号：
(1)オレンジ：2019-12-15 06:11 UTC フィリピン M6.9
(2)紫：2019-12-16 11:25 UTC 台湾宜蘭 M4.9

Hualien Jian North Station Quake Signals:
(1)Orange: 2019-12-15 06:11 UTC Philippines M6.9
(2)Purple: 2019-12-16 11:25 UTC Yilan, Taiwan M4.9

            
台灣地震預測研究所 所長 林湧森
台湾地震予測研究所 所長 林湧森
Dyson Lin, Founder & CEO, Taiwan Quake Forecast Institute
2019-12-17 10:58 UTC+8

# %%
insert_enter()
insert_Analysis_file(1)
insert_Analysis_file(2)

# %%
CWB signals could predict the 2019-12-16 11:25 UTC 宜蘭 宜蘭 Yilan M5.0 quake 9 days before it happened.

2019-12-16 11:25 UTC 宜蘭 宜蘭 Yilan M5.0
    
In 2017, I found Purple meant an M5+~M6+ quake will happen near that area within a few days.

In 2018, Taiwan Government fined me NTD 200,000 for my discovery.

They should let me be Head of CWB(Central Weather Bureau).
Then Taiwan Government will be the only government that can predict quakes.

台灣地震預測研究所 所長 林湧森
台湾地震予測研究所 所長 林湧森
Dyson Lin, Founder & CEO, Taiwan Quake Forecast Institute
2019-12-31 01:16 UTC+8

# %%
name_new_files(file_number=2, to_WeChat=False, date_stamp='2020-01-02')

# %%
name_new_files(file_number=1, to_WeChat=True, date_stamp='2020-01-02')

# %%
analyze_file(1)

# %%
analyze_file(2)

# %%
analyze_file(3)

# %%
analyze_file(4)

# %%
analyze_file(5)

# %%
analyze_file(6)

# %%
# 綠

insert_files(1)
station_name = station['日本大阪站']

languages = ['Chinese', 'Japanese', 'English']
quake_forecast = [
    {'color': Green,
     'time': 14,
     'location': {
        'Chinese': '日本廣島附近、南加州、墨西哥、菲律賓或印尼，',
        'Japanese': '日本広島付近、南カリフォルニア、メキシコ、フィリピンまたはインドネシア、',
        'English': 'Near Hiroshima, Japan, South California, Mexico, Philippines or Indonesia, '},
     'magnitude': 'M8+~M9+'},
]

time_stamp = get_time_stamp()
(blog_title, blog_title_str) = publish_Quake_Forecast(quake_forecast, 
                                    station_name, languages, time_stamp)
view_blog()

# %%
close_Blogger_article_list()
blog_address = get_blog_address()

post_Quake_Forecast(quake_forecast, 
                    station_name, time_stamp, blog_address, blog_title_str)

# %%
# 橙

insert_files(1)
station_name = station['新竹綠光站']

languages = ['Chinese', 'Japanese', 'English']
quake_forecast = [
    {'color': Orange,
     'time': 6,
     'location': {
        'Chinese': '泰國、尼泊爾或南美洲，',
        'Japanese': 'タイ、ネパールまたは南米、',
        'English': 'Thailand, Nepal or South America, '},
     'magnitude': 'M6+~M7+'},
]

time_stamp = get_time_stamp()
(blog_title, blog_title_str) = publish_Quake_Forecast(quake_forecast, 
                                    station_name, languages, time_stamp)
view_blog()

# %%
close_Blogger_article_list()
blog_address = get_blog_address()
post_Quake_Forecast(quake_forecast, 
                    station_name, time_stamp, blog_address, blog_title_str)

# %%
# 紫

insert_files(1)
station_name = station['新竹綠光站']

languages = ['Chinese', 'Japanese', 'English']
quake_forecast = [
    {'color': Purple,
     'time': 14,
     'location': {
        'Chinese': '東台灣，',
        'Japanese': '東台湾、',
        'English': 'East Taiwan, '},
     'magnitude': 'M5+~M6+'},
]

time_stamp = get_time_stamp()
(blog_title, blog_title_str) = publish_Quake_Forecast(quake_forecast, 
                                    station_name, languages, time_stamp)
view_blog()
# Out:
# ---------------------------------------------------------------------------
# FailSafeException                         Traceback (most recent call last)
# <ipython-input-297-77721ef4a86c> in <module>
#      17 time_stamp = get_time_stamp()
#      18 (blog_title, blog_title_str) = publish_Quake_Forecast(quake_forecast,
# ---> 19                                     station_name, languages, time_stamp)
#      20 view_blog()
#
# <ipython-input-1-72de91535466> in publish_Quake_Forecast(quake_forecast, station_name, languages, time_stamp)
#     810     set_blog_title()
#     811     get_Quake_Forecast_text(quake_forecast, station_name, languages, time_stamp)
# --> 812     set_blog_text()
#     813     publish_blog()
#     814     time.sleep(15)
#
# <ipython-input-1-72de91535466> in set_blog_text()
#     609     click_Blogger_tab()
#     610     scroll_down()
# --> 611     click_Edit_area()
#     612     pyautogui.press('backspace')
#     613
#
# <ipython-input-1-72de91535466> in click_Edit_area()
#      66     pyautogui.moveTo(1100, 990)
#      67     time.sleep(1)
# ---> 68     pyautogui.click()
#      69     time.sleep(1)
#      70
#
# C:\Anaconda3\lib\site-packages\pyautogui\__init__.py in click(x, y, clicks, interval, button, duration, tween, pause, logScreenshot, _pause)
#     518     """
#     519     button = _translateButton(button)
# --> 520     failSafeCheck()
#     521     x, y = _unpackXY(x, y)
#     522
#
# C:\Anaconda3\lib\site-packages\pyautogui\__init__.py in failSafeCheck()
#    1255 def failSafeCheck():
#    1256     if FAILSAFE and tuple(position()) in FAILSAFE_POINTS:
# -> 1257         raise FailSafeException('PyAutoGUI fail-safe triggered from mouse moving to a corner of the screen. To disable this fail-safe, set pyautogui.FAILSAFE to False. DISABLING FAIL-SAFE IS NOT RECOMMENDED.')
#    1258
#    1259
#
# FailSafeException: PyAutoGUI fail-safe triggered from mouse moving to a corner of the screen. To disable this fail-safe, set pyautogui.FAILSAFE to False. DISABLING FAIL-SAFE IS NOT RECOMMENDED.

# %%
close_Blogger_article_list()
blog_address = get_blog_address()
post_Quake_Forecast(quake_forecast, 
                    station_name, time_stamp, blog_address, blog_title_str)

# %%
# 紅

insert_files(1)
station_name = station['宜蘭站']

languages = ['Chinese', 'Japanese', 'English']
quake_forecast = [
    {'color': Red,
     'time': 2,
     'location': {
        'Chinese': '花蓮或宜蘭，',
        'Japanese': '花蓮または宜蘭、',
        'English': 'Hualien or Yilan, '},
     'magnitude': 'M3+~M4+'},
]

time_stamp = get_time_stamp()
(blog_title, blog_title_str) = publish_Quake_Forecast(quake_forecast, 
                                    station_name, languages, time_stamp)
view_blog()

# %%
close_Blogger_article_list()
blog_address = get_blog_address()
post_Quake_Forecast(quake_forecast, 
                    station_name, time_stamp, blog_address, blog_title_str)

# %%
# 黃

insert_files(1)
station_name = station['土耳其伊斯坦堡庫科切梅切站']

languages = ['Chinese', 'Japanese', 'English']
quake_forecast = [
    {'color': Yellow,
     'time': 6,
     'location': {
        'Chinese': '土耳其伊斯坦堡附近，',
        'Japanese': 'トルコ イスタンブール付近、',
        'English': 'Near Istanbul, Turkey, '},
     'magnitude': 'M4+~M5+'},
]

time_stamp = get_time_stamp()
(blog_title, blog_title_str) = publish_Quake_Forecast(quake_forecast, 
                                    station_name, languages, time_stamp)
view_blog()

# %%
close_Blogger_article_list()
blog_address = get_blog_address()

post_Quake_Forecast(quake_forecast, 
                    station_name, time_stamp, blog_address, blog_title_str)

# %%
# 黃

#insert_files(1)
station_name = station['義大利馬切拉塔站']

languages = ['Chinese', 'Japanese', 'English']
quake_forecast = [
    {'color': Yellow,
     'time': 1,
     'location': {
        'Chinese': '南義大利、阿爾巴尼亞、希臘或土耳其，',
        'Japanese': '南イタリア、アルバニア、ギリシャまたはトルコ、',
        'English': 'South Italy, Albania, Greece or Turkey, '},
     'magnitude': 'M4+~M5+'},
]

time_stamp = get_time_stamp()
(blog_title, blog_title_str) = publish_Quake_Forecast(quake_forecast, 
                                    station_name, languages, time_stamp)
view_blog()

# %%
close_Blogger_article_list()
blog_a2019-12-25 高雄小港站 Kaohsiung Xiaogang Station 空氣2號 Air 2 (OrangePi One + Arduino Uno + TL081) 1 - Analysisddress = get_blog_address()
post_Quake_Forecast(quake_forecast, 
                    station_name, time_stamp, blog_address, blog_title_str)

# %%
1995-01-16 20:46 UTC 日本 日本 Japan M6.9
2011-03-11 05:46 UTC 日本 日本 Japan M9.1
